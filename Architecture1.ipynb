# %%
from psutil import virtual_memory
ram_gb = virtual_memory().total / 1e9
print('Your runtime has {:.1f} gigabytes of available RAM\n'.format(ram_gb))
# Out:
# Your runtime has 13.6 gigabytes of available RAM

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.optim.lr_scheduler import _LRScheduler
import torch.utils.data as data

import torchvision.transforms as transforms
import torchvision.datasets as datasets

from sklearn import decomposition
from sklearn import manifold
from sklearn.metrics import confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay
import matplotlib.pyplot as plt
import numpy as np

import copy
import random
import time

# %%
SEED = 1234

random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
torch.cuda.manual_seed(SEED)
torch.backends.cudnn.deterministic = True

# %% [markdown]
# DATA

# %%
ROOT = '.data'
train_data = datasets.CIFAR10(root = ROOT, 
                              train = True, 
                              download = True)
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to .data/cifar-10-python.tar.gz
#   0%|          | 0/170498071 [00:00<?, ?it/s]
# Extracting .data/cifar-10-python.tar.gz to .data

# %%
means = train_data.data.mean(axis = (0,1,2)) / 255
stds = train_data.data.std(axis = (0,1,2)) / 255

# %%
train_transforms = transforms.Compose([
                           transforms.RandomRotation(5),
                           transforms.RandomHorizontalFlip(0.5),
                           transforms.RandomCrop(32, padding = 2),
                           transforms.ToTensor(),
                           transforms.Normalize(mean = means, 
                                                std = stds)
                       ])

test_transforms = transforms.Compose([
                           transforms.ToTensor(),
                           transforms.Normalize(mean = means, 
                                                std = stds)
                       ])

# %%
train_data = datasets.CIFAR10(ROOT, 
                              train = True, 
                              download = True, 
                              transform = train_transforms)

test_data = datasets.CIFAR10(ROOT, 
                             train = False, 
                             download = True, 
                             transform = test_transforms)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
VALID_RATIO = 0.9

n_train_examples = int(len(train_data) * VALID_RATIO)
n_valid_examples = len(train_data) - n_train_examples

train_data, valid_data = data.random_split(train_data, 
                                           [n_train_examples, n_valid_examples])

# %%
valid_data = copy.deepcopy(valid_data)
valid_data.dataset.transform = test_transforms

# %%
BATCH_SIZE = 128

train_iterator = torch.utils.data.DataLoader(train_data, BATCH_SIZE, shuffle = True)

valid_iterator = torch.utils.data.DataLoader(valid_data, BATCH_SIZE, shuffle = True)

test_iterator = torch.utils.data.DataLoader(test_data, BATCH_SIZE, shuffle = True)

# %%
class ResBlock(nn.Module):
    def __init__(self, in_channels, out_channels, downsample):
        super().__init__()
        if downsample:
            self.conv1 = nn.Conv2d(
                in_channels, out_channels, kernel_size=3, stride=2, padding=1)
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_channels, out_channels, kernel_size=1, stride=2),
                nn.BatchNorm2d(out_channels)
            )
        else:
            self.conv1 = nn.Conv2d(
                in_channels, out_channels, kernel_size=3, stride=1, padding=1)
            self.shortcut = nn.Sequential()

        self.conv2 = nn.Conv2d(out_channels, out_channels,
                               kernel_size=3, stride=1, padding=1)
        self.bn1 = nn.BatchNorm2d(out_channels)
        self.bn2 = nn.BatchNorm2d(out_channels)

    def forward(self, input):
        shortcut = self.shortcut(input)
        input = nn.ReLU()(self.bn1(self.conv1(input)))
        input = nn.ReLU()(self.bn2(self.conv2(input)))
        input = input + shortcut
        return nn.ReLU()(input)

# %%
class ResNet(nn.Module):
    def __init__(self, in_channels, resblock, repeat, useBottleneck=False, outputs=1000):
        super().__init__()
        self.layer0 = nn.Sequential(
            nn.Conv2d(in_channels, 64, kernel_size=3, stride=1, padding=1),
            nn.MaxPool2d(kernel_size=5, stride=3, padding=1),
            nn.BatchNorm2d(64),
            nn.ReLU()
        )

        if useBottleneck:
            filters = [64, 256, 512, 1024, 2048]
        else:
            filters = [64, 64, 128, 256, 242]

        self.layer1 = nn.Sequential()
        self.layer1.add_module('conv2_1', resblock(filters[0], filters[1], downsample=False))
        for i in range(1, repeat[0]):
                self.layer1.add_module('conv2_%d'%(i+1,), resblock(filters[1], filters[1], downsample=False))

        self.layer2 = nn.Sequential()
        self.layer2.add_module('conv3_1', resblock(filters[1], filters[2], downsample=True))
        for i in range(1, repeat[1]):
                self.layer2.add_module('conv3_%d' % (
                    i+1,), resblock(filters[2], filters[2], downsample=False))

        self.layer3 = nn.Sequential()
        self.layer3.add_module('conv4_1', resblock(filters[2], filters[3], downsample=True))
        for i in range(1, repeat[2]):
            self.layer3.add_module('conv2_%d' % (
                i+1,), resblock(filters[3], filters[3], downsample=False))

        self.layer4 = nn.Sequential()
        self.layer4.add_module('conv5_1', resblock(filters[3], filters[4], downsample=True))
        for i in range(1, repeat[3]):
            self.layer4.add_module('conv3_%d'%(i+1,),resblock(filters[4], filters[4], downsample=False))

        self.gap = torch.nn.AdaptiveAvgPool2d(1)
        self.fc = torch.nn.Linear(filters[4], outputs)

    def forward(self, input):
        input = self.layer0(input)
        input = self.layer1(input)
        input = self.layer2(input)
        input = self.layer3(input)
        input = self.layer4(input)
        input = self.gap(input)
        # torch.flatten()
        # https://stackoverflow.com/questions/60115633/pytorch-flatten-doesnt-maintain-batch-size
        input = torch.flatten(input, start_dim=1)
        input = self.fc(input)

        return input

# %%
from torchsummary import summary



resnet18 = ResNet(3, ResBlock, [2, 2, 2, 2], useBottleneck=False, outputs=10)
resnet18.to(torch.device("cuda:0" if torch.cuda.is_available() else "cpu"))
summary(resnet18, (3, 32, 32))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 64, 32, 32]           1,792
#          MaxPool2d-2           [-1, 64, 10, 10]               0
#        BatchNorm2d-3           [-1, 64, 10, 10]             128
#               ReLU-4           [-1, 64, 10, 10]               0
#             Conv2d-5           [-1, 64, 10, 10]          36,928
#        BatchNorm2d-6           [-1, 64, 10, 10]             128
#             Conv2d-7           [-1, 64, 10, 10]          36,928
#        BatchNorm2d-8           [-1, 64, 10, 10]             128
#           ResBlock-9           [-1, 64, 10, 10]               0
#            Conv2d-10           [-1, 64, 10, 10]          36,928
#       BatchNorm2d-11           [-1, 64, 10, 10]             128
#            Conv2d-12           [-1, 64, 10, 10]          36,928
#       BatchNorm2d-13           [-1, 64, 10, 10]             128
#          ResBlock-14           [-1, 64, 10, 10]               0
#            Conv2d-15            [-1, 128, 5, 5]           8,320
#       BatchNorm2d-16            [-1, 128, 5, 5]             256
#            Conv2d-17            [-1, 128, 5, 5]          73,856
#       BatchNorm2d-18            [-1, 128, 5, 5]             256
#            Conv2d-19            [-1, 128, 5, 5]         147,584
#       BatchNorm2d-20            [-1, 128, 5, 5]             256
#          ResBlock-21            [-1, 128, 5, 5]               0
#            Conv2d-22            [-1, 128, 5, 5]         147,584
#       BatchNorm2d-23            [-1, 128, 5, 5]             256
#            Conv2d-24            [-1, 128, 5, 5]         147,584
#       BatchNorm2d-25            [-1, 128, 5, 5]             256
#          ResBlock-26            [-1, 128, 5, 5]               0
#            Conv2d-27            [-1, 256, 3, 3]          33,024
#       BatchNorm2d-28            [-1, 256, 3, 3]             512
#            Conv2d-29            [-1, 256, 3, 3]         295,168
#       BatchNorm2d-30            [-1, 256, 3, 3]             512
#            Conv2d-31            [-1, 256, 3, 3]         590,080
#       BatchNorm2d-32            [-1, 256, 3, 3]             512
#          ResBlock-33            [-1, 256, 3, 3]               0
#            Conv2d-34            [-1, 256, 3, 3]         590,080
#       BatchNorm2d-35            [-1, 256, 3, 3]             512
#            Conv2d-36            [-1, 256, 3, 3]         590,080
#       BatchNorm2d-37            [-1, 256, 3, 3]             512
#          ResBlock-38            [-1, 256, 3, 3]               0
#            Conv2d-39            [-1, 242, 2, 2]          62,194
#       BatchNorm2d-40            [-1, 242, 2, 2]             484
#            Conv2d-41            [-1, 242, 2, 2]         557,810
#       BatchNorm2d-42            [-1, 242, 2, 2]             484
#            Conv2d-43            [-1, 242, 2, 2]         527,318
#       BatchNorm2d-44            [-1, 242, 2, 2]             484
#          ResBlock-45            [-1, 242, 2, 2]               0
#            Conv2d-46            [-1, 242, 2, 2]         527,318
#       BatchNorm2d-47            [-1, 242, 2, 2]             484
#            Conv2d-48            [-1, 242, 2, 2]         527,318
#       BatchNorm2d-49            [-1, 242, 2, 2]             484
#          ResBlock-50            [-1, 242, 2, 2]               0
# AdaptiveAvgPool2d-51            [-1, 242, 1, 1]               0
#            Linear-52                   [-1, 10]           2,430
# ================================================================
# Total params: 4,984,152
# Trainable params: 4,984,152
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 1.73
# Params size (MB): 19.01
# Estimated Total Size (MB): 20.75
# ----------------------------------------------------------------

# %%
# summary(model, (3,32,32))

# %%
optimizer = optim.SGD(resnet18.parameters(), lr = 0.01, momentum=0.9)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
criterion = nn.CrossEntropyLoss()

criterion = criterion.to(device)

# %%
def calculate_accuracy(y_pred, y):
    top_pred = y_pred.argmax(1, keepdim = True)
    correct = top_pred.eq(y.view_as(top_pred)).sum()
    acc = correct.float() / y.shape[0]
    return acc

# %%
def train(model, iterator, optimizer, criterion, device):
    
    epoch_loss = 0
    epoch_acc = 0
    
    model.train()
    
    for (x, y) in iterator:
        
        x = x.to(device)
        y = y.to(device)
        
        optimizer.zero_grad()
                
        y_pred = model(x)
        
        loss = criterion(y_pred, y)
        
        acc = calculate_accuracy(y_pred, y)
        
        loss.backward()
        
        optimizer.step()
        
        epoch_loss += loss.item()
        epoch_acc += acc.item()
        
    return epoch_loss / len(iterator), epoch_acc / len(iterator)

# %%
def evaluate(model, iterator, criterion, device):
    
    epoch_loss = 0
    epoch_acc = 0
    
    model.eval()
    
    with torch.no_grad():
        
        for (x, y) in iterator:

            x = x.to(device)
            y = y.to(device)

            y_pred = model(x)

            loss = criterion(y_pred, y)

            acc = calculate_accuracy(y_pred, y)

            epoch_loss += loss.item()
            epoch_acc += acc.item()
        
    return epoch_loss / len(iterator), epoch_acc / len(iterator)

# %%
def epoch_time(start_time, end_time):
    elapsed_time = end_time - start_time
    elapsed_mins = int(elapsed_time / 60)
    elapsed_secs = int(elapsed_time - (elapsed_mins * 60))
    return elapsed_mins, elapsed_secs

# %%
import math
import time

EPOCHS = 200
train_loss_list = []
val_loss_list = []
train_acc_list = []
val_acc_list = []
#Setting a min variable to store model with minimum loss and then store that model
min = math.inf
for e in range(EPOCHS):
  start_time = time.time()
  train_loss, train_accuracy = train(resnet18, train_iterator, optimizer, criterion, device)
  valid_loss, valid_accuracy = evaluate(resnet18, valid_iterator, criterion, device)
  print("For Epoch %d, Training Loss is %f and Training Accuracy is %f" %(e+1, train_loss, train_accuracy*100))
  print("For Epoch %d, Validation Loss is %f and Validation Accuracy is %f" %(e+1, valid_loss, valid_accuracy*100))
  train_acc_list.append(train_accuracy)
  val_acc_list.append(valid_accuracy)
  train_loss_list.append(train_loss)
  val_loss_list.append(valid_loss)
  #using torch.save() to store the best model i.e. the one with minimum validation loss
  if valid_loss < min:
    torch.save(resnet18.state_dict(), '/content/best_model.pt')
  end_time = time.time()
  elapsed_mins, elapsed_secs = epoch_time(start_time, end_time)
  print("Time for epoch %d is %f mins %f secs \n" % (e+1, elapsed_mins, elapsed_secs))
# Out:
# For Epoch 1, Training Loss is 1.430698 and Training Accuracy is 48.268081
# For Epoch 1, Validation Loss is 1.232708 and Validation Accuracy is 57.285156
# Time for epoch 1 is 0.000000 mins 29.000000 secs
#
# For Epoch 2, Training Loss is 1.058340 and Training Accuracy is 61.880277
# For Epoch 2, Validation Loss is 0.960065 and Validation Accuracy is 67.031250
# Time for epoch 2 is 0.000000 mins 29.000000 secs
#
# For Epoch 3, Training Loss is 0.905331 and Training Accuracy is 67.898467
# For Epoch 3, Validation Loss is 0.843241 and Validation Accuracy is 70.976562
# Time for epoch 3 is 0.000000 mins 28.000000 secs
#
# For Epoch 4, Training Loss is 0.789083 and Training Accuracy is 72.202740
# For Epoch 4, Validation Loss is 0.805124 and Validation Accuracy is 72.539062
# Time for epoch 4 is 0.000000 mins 28.000000 secs
#
# For Epoch 5, Training Loss is 0.727956 and Training Accuracy is 74.674972
# For Epoch 5, Validation Loss is 0.720283 and Validation Accuracy is 75.546875
# Time for epoch 5 is 0.000000 mins 28.000000 secs
#
# For Epoch 6, Training Loss is 0.662390 and Training Accuracy is 76.750168
# For Epoch 6, Validation Loss is 0.651569 and Validation Accuracy is 77.402344
# Time for epoch 6 is 0.000000 mins 28.000000 secs
#
# For Epoch 7, Training Loss is 0.610400 and Training Accuracy is 78.494417
# For Epoch 7, Validation Loss is 0.687790 and Validation Accuracy is 76.738281
# Time for epoch 7 is 0.000000 mins 29.000000 secs
#
# For Epoch 8, Training Loss is 0.574605 and Training Accuracy is 79.685281
# For Epoch 8, Validation Loss is 0.616948 and Validation Accuracy is 79.589844
# Time for epoch 8 is 0.000000 mins 28.000000 secs
#
# For Epoch 9, Training Loss is 0.539973 and Training Accuracy is 80.951853
# For Epoch 9, Validation Loss is 0.615948 and Validation Accuracy is 79.921875
# Time for epoch 9 is 0.000000 mins 28.000000 secs
#
# For Epoch 10, Training Loss is 0.505707 and Training Accuracy is 82.229768
# For Epoch 10, Validation Loss is 0.612013 and Validation Accuracy is 80.292969
# Time for epoch 10 is 0.000000 mins 28.000000 secs
#
# For Epoch 11, Training Loss is 0.480940 and Training Accuracy is 83.157996
# For Epoch 11, Validation Loss is 0.631169 and Validation Accuracy is 78.789062
# Time for epoch 11 is 0.000000 mins 28.000000 secs
#
# For Epoch 12, Training Loss is 0.454680 and Training Accuracy is 83.919024
# For Epoch 12, Validation Loss is 0.561759 and Validation Accuracy is 81.542969
# Time for epoch 12 is 0.000000 mins 29.000000 secs
#
# For Epoch 13, Training Loss is 0.433600 and Training Accuracy is 84.563408
# For Epoch 13, Validation Loss is 0.618263 and Validation Accuracy is 81.132812
# Time for epoch 13 is 0.000000 mins 28.000000 secs
#
# For Epoch 14, Training Loss is 0.408554 and Training Accuracy is 85.656122
# For Epoch 14, Validation Loss is 0.568498 and Validation Accuracy is 81.660156
# Time for epoch 14 is 0.000000 mins 28.000000 secs
#
# For Epoch 15, Training Loss is 0.389729 and Training Accuracy is 86.433426
# For Epoch 15, Validation Loss is 0.601872 and Validation Accuracy is 81.250000
# Time for epoch 15 is 0.000000 mins 28.000000 secs
#
# For Epoch 16, Training Loss is 0.370118 and Training Accuracy is 86.958205
# For Epoch 16, Validation Loss is 0.577276 and Validation Accuracy is 82.207031
# Time for epoch 16 is 0.000000 mins 28.000000 secs
#
# For Epoch 17, Training Loss is 0.358168 and Training Accuracy is 87.516769
# For Epoch 17, Validation Loss is 0.504973 and Validation Accuracy is 83.847656
# Time for epoch 17 is 0.000000 mins 28.000000 secs
#
# For Epoch 18, Training Loss is 0.342450 and Training Accuracy is 87.802586
# For Epoch 18, Validation Loss is 0.558652 and Validation Accuracy is 82.050781
# Time for epoch 18 is 0.000000 mins 28.000000 secs
#
# For Epoch 19, Training Loss is 0.326805 and Training Accuracy is 88.488400
# For Epoch 19, Validation Loss is 0.547381 and Validation Accuracy is 83.476562
# Time for epoch 19 is 0.000000 mins 28.000000 secs
#
# For Epoch 20, Training Loss is 0.309471 and Training Accuracy is 88.920701
# For Epoch 20, Validation Loss is 0.626005 and Validation Accuracy is 81.523438
# Time for epoch 20 is 0.000000 mins 28.000000 secs
#
# For Epoch 21, Training Loss is 0.298375 and Training Accuracy is 89.331055
# For Epoch 21, Validation Loss is 0.564842 and Validation Accuracy is 83.183594
# Time for epoch 21 is 0.000000 mins 28.000000 secs
#
# For Epoch 22, Training Loss is 0.288377 and Training Accuracy is 89.830433
# For Epoch 22, Validation Loss is 0.528266 and Validation Accuracy is 84.433594
# Time for epoch 22 is 0.000000 mins 28.000000 secs
#
# For Epoch 23, Training Loss is 0.268638 and Training Accuracy is 90.344608
# For Epoch 23, Validation Loss is 0.621573 and Validation Accuracy is 82.128906
# Time for epoch 23 is 0.000000 mins 29.000000 secs
#
# For Epoch 24, Training Loss is 0.263595 and Training Accuracy is 90.636837
# For Epoch 24, Validation Loss is 0.584289 and Validation Accuracy is 82.011719
# Time for epoch 24 is 0.000000 mins 28.000000 secs
#
# For Epoch 25, Training Loss is 0.254006 and Training Accuracy is 91.077277
# For Epoch 25, Validation Loss is 0.567061 and Validation Accuracy is 83.007812
# Time for epoch 25 is 0.000000 mins 28.000000 secs
#
# For Epoch 26, Training Loss is 0.241249 and Training Accuracy is 91.366793
# For Epoch 26, Validation Loss is 0.603376 and Validation Accuracy is 82.695312
# Time for epoch 26 is 0.000000 mins 28.000000 secs
#
# For Epoch 27, Training Loss is 0.236190 and Training Accuracy is 91.466915
# For Epoch 27, Validation Loss is 0.601078 and Validation Accuracy is 82.773438
# Time for epoch 27 is 0.000000 mins 28.000000 secs
#
# For Epoch 28, Training Loss is 0.219563 and Training Accuracy is 92.169991
# For Epoch 28, Validation Loss is 0.584986 and Validation Accuracy is 83.691406
# Time for epoch 28 is 0.000000 mins 28.000000 secs
#
# For Epoch 29, Training Loss is 0.218530 and Training Accuracy is 92.232136
# For Epoch 29, Validation Loss is 0.595233 and Validation Accuracy is 83.085938
# Time for epoch 29 is 0.000000 mins 28.000000 secs
#
# For Epoch 30, Training Loss is 0.204572 and Training Accuracy is 92.719184
# For Epoch 30, Validation Loss is 0.598607 and Validation Accuracy is 83.652344
# Time for epoch 30 is 0.000000 mins 28.000000 secs
#
# For Epoch 31, Training Loss is 0.200012 and Training Accuracy is 92.809689
# For Epoch 31, Validation Loss is 0.565444 and Validation Accuracy is 84.531250
# Time for epoch 31 is 0.000000 mins 28.000000 secs
#
# For Epoch 32, Training Loss is 0.190949 and Training Accuracy is 93.217330
# For Epoch 32, Validation Loss is 0.591917 and Validation Accuracy is 83.730469
# Time for epoch 32 is 0.000000 mins 28.000000 secs
#
# For Epoch 33, Training Loss is 0.186152 and Training Accuracy is 93.341619
# For Epoch 33, Validation Loss is 0.564452 and Validation Accuracy is 85.332031
# Time for epoch 33 is 0.000000 mins 28.000000 secs
#
# For Epoch 34, Training Loss is 0.178479 and Training Accuracy is 93.746794
# For Epoch 34, Validation Loss is 0.611058 and Validation Accuracy is 83.789062
# Time for epoch 34 is 0.000000 mins 28.000000 secs
#
# For Epoch 35, Training Loss is 0.165526 and Training Accuracy is 94.107580
# For Epoch 35, Validation Loss is 0.602153 and Validation Accuracy is 84.199219
# Time for epoch 35 is 0.000000 mins 28.000000 secs
#
# For Epoch 36, Training Loss is 0.165220 and Training Accuracy is 94.105114
# For Epoch 36, Validation Loss is 0.646255 and Validation Accuracy is 83.984375
# Time for epoch 36 is 0.000000 mins 28.000000 secs
#
# For Epoch 37, Training Loss is 0.159038 and Training Accuracy is 94.338897
# For Epoch 37, Validation Loss is 0.600229 and Validation Accuracy is 85.019531
# Time for epoch 37 is 0.000000 mins 28.000000 secs
#
# For Epoch 38, Training Loss is 0.154872 and Training Accuracy is 94.523605
# For Epoch 38, Validation Loss is 0.634131 and Validation Accuracy is 84.023438
# Time for epoch 38 is 0.000000 mins 28.000000 secs
#
# For Epoch 39, Training Loss is 0.145460 and Training Accuracy is 94.969470
# For Epoch 39, Validation Loss is 0.606940 and Validation Accuracy is 84.667969
# Time for epoch 39 is 0.000000 mins 28.000000 secs
#
# For Epoch 40, Training Loss is 0.141020 and Training Accuracy is 94.933219
# For Epoch 40, Validation Loss is 0.624501 and Validation Accuracy is 85.292969
# Time for epoch 40 is 0.000000 mins 28.000000 secs
#
# For Epoch 41, Training Loss is 0.138229 and Training Accuracy is 95.186484
# For Epoch 41, Validation Loss is 0.607939 and Validation Accuracy is 84.375000
# Time for epoch 41 is 0.000000 mins 28.000000 secs
#
# For Epoch 42, Training Loss is 0.131831 and Training Accuracy is 95.315459
# For Epoch 42, Validation Loss is 0.666882 and Validation Accuracy is 83.710938
# Time for epoch 42 is 0.000000 mins 28.000000 secs
#
# For Epoch 43, Training Loss is 0.128631 and Training Accuracy is 95.381550
# For Epoch 43, Validation Loss is 0.612167 and Validation Accuracy is 84.804688
# Time for epoch 43 is 0.000000 mins 28.000000 secs
#
# For Epoch 44, Training Loss is 0.125145 and Training Accuracy is 95.428652
# For Epoch 44, Validation Loss is 0.656535 and Validation Accuracy is 84.316406
# Time for epoch 44 is 0.000000 mins 28.000000 secs
#
# For Epoch 45, Training Loss is 0.118864 and Training Accuracy is 95.803987
# For Epoch 45, Validation Loss is 0.623607 and Validation Accuracy is 85.507812
# Time for epoch 45 is 0.000000 mins 27.000000 secs
#
# For Epoch 46, Training Loss is 0.113870 and Training Accuracy is 96.046895
# For Epoch 46, Validation Loss is 0.633373 and Validation Accuracy is 84.375000
# Time for epoch 46 is 0.000000 mins 28.000000 secs
#
# For Epoch 47, Training Loss is 0.113860 and Training Accuracy is 95.923838
# For Epoch 47, Validation Loss is 0.632414 and Validation Accuracy is 84.511719
# Time for epoch 47 is 0.000000 mins 27.000000 secs
#
# For Epoch 48, Training Loss is 0.108139 and Training Accuracy is 96.121863
# For Epoch 48, Validation Loss is 0.619714 and Validation Accuracy is 85.175781
# Time for epoch 48 is 0.000000 mins 28.000000 secs
#
# For Epoch 49, Training Loss is 0.105228 and Training Accuracy is 96.323341
# For Epoch 49, Validation Loss is 0.643840 and Validation Accuracy is 85.273438
# Time for epoch 49 is 0.000000 mins 28.000000 secs
#
# For Epoch 50, Training Loss is 0.103940 and Training Accuracy is 96.256757
# For Epoch 50, Validation Loss is 0.661132 and Validation Accuracy is 85.195312
# Time for epoch 50 is 0.000000 mins 28.000000 secs
#
# For Epoch 51, Training Loss is 0.097373 and Training Accuracy is 96.482156
# For Epoch 51, Validation Loss is 0.625525 and Validation Accuracy is 85.722656
# Time for epoch 51 is 0.000000 mins 27.000000 secs
#
# For Epoch 52, Training Loss is 0.095641 and Training Accuracy is 96.554165
# For Epoch 52, Validation Loss is 0.646723 and Validation Accuracy is 85.312500
# Time for epoch 52 is 0.000000 mins 28.000000 secs
#
# For Epoch 53, Training Loss is 0.092941 and Training Accuracy is 96.649108
# For Epoch 53, Validation Loss is 0.655405 and Validation Accuracy is 85.097656
# Time for epoch 53 is 0.000000 mins 28.000000 secs
#
# For Epoch 54, Training Loss is 0.087066 and Training Accuracy is 96.888563
# For Epoch 54, Validation Loss is 0.707466 and Validation Accuracy is 84.824219
# Time for epoch 54 is 0.000000 mins 28.000000 secs
#
# For Epoch 55, Training Loss is 0.086031 and Training Accuracy is 97.025677
# For Epoch 55, Validation Loss is 0.662980 and Validation Accuracy is 85.117188
# Time for epoch 55 is 0.000000 mins 28.000000 secs
#
# For Epoch 56, Training Loss is 0.086384 and Training Accuracy is 96.837023
# For Epoch 56, Validation Loss is 0.693302 and Validation Accuracy is 85.058594
# Time for epoch 56 is 0.000000 mins 27.000000 secs
#
# For Epoch 57, Training Loss is 0.085727 and Training Accuracy is 96.887084
# For Epoch 57, Validation Loss is 0.708244 and Validation Accuracy is 84.492188
# Time for epoch 57 is 0.000000 mins 28.000000 secs
#
# For Epoch 58, Training Loss is 0.085178 and Training Accuracy is 97.010634
# For Epoch 58, Validation Loss is 0.734579 and Validation Accuracy is 84.218750
# Time for epoch 58 is 0.000000 mins 28.000000 secs
#
# For Epoch 59, Training Loss is 0.081459 and Training Accuracy is 97.113469
# For Epoch 59, Validation Loss is 0.639761 and Validation Accuracy is 86.035156
# Time for epoch 59 is 0.000000 mins 28.000000 secs
#
# For Epoch 60, Training Loss is 0.076090 and Training Accuracy is 97.363281
# For Epoch 60, Validation Loss is 0.655547 and Validation Accuracy is 85.625000
# Time for epoch 60 is 0.000000 mins 27.000000 secs
#
# For Epoch 61, Training Loss is 0.078191 and Training Accuracy is 97.231100
# For Epoch 61, Validation Loss is 0.696420 and Validation Accuracy is 85.371094
# Time for epoch 61 is 0.000000 mins 28.000000 secs
#
# For Epoch 62, Training Loss is 0.075808 and Training Accuracy is 97.355883
# For Epoch 62, Validation Loss is 0.689227 and Validation Accuracy is 84.355469
# Time for epoch 62 is 0.000000 mins 28.000000 secs
#
# For Epoch 63, Training Loss is 0.072423 and Training Accuracy is 97.388682
# For Epoch 63, Validation Loss is 0.695417 and Validation Accuracy is 85.234375
# Time for epoch 63 is 0.000000 mins 28.000000 secs
#
# For Epoch 64, Training Loss is 0.070784 and Training Accuracy is 97.478447
# For Epoch 64, Validation Loss is 0.696228 and Validation Accuracy is 84.921875
# Time for epoch 64 is 0.000000 mins 28.000000 secs
#
# For Epoch 65, Training Loss is 0.071009 and Training Accuracy is 97.503107
# For Epoch 65, Validation Loss is 0.678406 and Validation Accuracy is 85.136719
# Time for epoch 65 is 0.000000 mins 27.000000 secs
#
# For Epoch 66, Training Loss is 0.068790 and Training Accuracy is 97.590159
# For Epoch 66, Validation Loss is 0.698981 and Validation Accuracy is 84.941406
# Time for epoch 66 is 0.000000 mins 28.000000 secs
#
# For Epoch 67, Training Loss is 0.063245 and Training Accuracy is 97.856988
# For Epoch 67, Validation Loss is 0.645076 and Validation Accuracy is 85.917969
# Time for epoch 67 is 0.000000 mins 28.000000 secs
#
# For Epoch 68, Training Loss is 0.060747 and Training Accuracy is 97.834300
# For Epoch 68, Validation Loss is 0.715948 and Validation Accuracy is 84.687500
# Time for epoch 68 is 0.000000 mins 27.000000 secs
#
# For Epoch 69, Training Loss is 0.064072 and Training Accuracy is 97.697187
# For Epoch 69, Validation Loss is 0.727707 and Validation Accuracy is 85.019531
# Time for epoch 69 is 0.000000 mins 28.000000 secs
#
# For Epoch 70, Training Loss is 0.058768 and Training Accuracy is 97.946999
# For Epoch 70, Validation Loss is 0.688775 and Validation Accuracy is 85.781250
# Time for epoch 70 is 0.000000 mins 27.000000 secs
#
# For Epoch 71, Training Loss is 0.061577 and Training Accuracy is 97.889787
# For Epoch 71, Validation Loss is 0.674468 and Validation Accuracy is 85.976562
# Time for epoch 71 is 0.000000 mins 27.000000 secs
#
# For Epoch 72, Training Loss is 0.059819 and Training Accuracy is 97.875730
# For Epoch 72, Validation Loss is 0.684824 and Validation Accuracy is 85.292969
# Time for epoch 72 is 0.000000 mins 28.000000 secs
#
# For Epoch 73, Training Loss is 0.054556 and Training Accuracy is 98.036271
# For Epoch 73, Validation Loss is 0.671593 and Validation Accuracy is 85.332031
# Time for epoch 73 is 0.000000 mins 27.000000 secs
#
# For Epoch 74, Training Loss is 0.062807 and Training Accuracy is 97.754399
# For Epoch 74, Validation Loss is 0.726755 and Validation Accuracy is 85.175781
# Time for epoch 74 is 0.000000 mins 27.000000 secs
#
# For Epoch 75, Training Loss is 0.051473 and Training Accuracy is 98.165493
# For Epoch 75, Validation Loss is 0.745525 and Validation Accuracy is 84.921875
# Time for epoch 75 is 0.000000 mins 28.000000 secs
#
# For Epoch 76, Training Loss is 0.054554 and Training Accuracy is 98.101128
# For Epoch 76, Validation Loss is 0.738342 and Validation Accuracy is 84.863281
# Time for epoch 76 is 0.000000 mins 27.000000 secs
#
# For Epoch 77, Training Loss is 0.050857 and Training Accuracy is 98.218267
# For Epoch 77, Validation Loss is 0.713731 and Validation Accuracy is 86.132812
# Time for epoch 77 is 0.000000 mins 28.000000 secs
#
# For Epoch 78, Training Loss is 0.049079 and Training Accuracy is 98.322581
# For Epoch 78, Validation Loss is 0.710856 and Validation Accuracy is 85.429688
# Time for epoch 78 is 0.000000 mins 28.000000 secs
#
# For Epoch 79, Training Loss is 0.051649 and Training Accuracy is 98.164260
# For Epoch 79, Validation Loss is 0.748066 and Validation Accuracy is 85.078125
# Time for epoch 79 is 0.000000 mins 27.000000 secs
#
# For Epoch 80, Training Loss is 0.053028 and Training Accuracy is 98.142312
# For Epoch 80, Validation Loss is 0.802695 and Validation Accuracy is 84.921875
# Time for epoch 80 is 0.000000 mins 27.000000 secs
#
# For Epoch 81, Training Loss is 0.049164 and Training Accuracy is 98.263149
# For Epoch 81, Validation Loss is 0.731795 and Validation Accuracy is 85.625000
# Time for epoch 81 is 0.000000 mins 28.000000 secs
#
# For Epoch 82, Training Loss is 0.048462 and Training Accuracy is 98.318142
# For Epoch 82, Validation Loss is 0.804990 and Validation Accuracy is 84.511719
# Time for epoch 82 is 0.000000 mins 28.000000 secs
#
# For Epoch 83, Training Loss is 0.046458 and Training Accuracy is 98.358586
# For Epoch 83, Validation Loss is 0.747360 and Validation Accuracy is 85.546875
# Time for epoch 83 is 0.000000 mins 28.000000 secs
#
# For Epoch 84, Training Loss is 0.051040 and Training Accuracy is 98.238242
# For Epoch 84, Validation Loss is 0.695806 and Validation Accuracy is 85.644531
# Time for epoch 84 is 0.000000 mins 28.000000 secs
#
# For Epoch 85, Training Loss is 0.045703 and Training Accuracy is 98.451803
# For Epoch 85, Validation Loss is 0.717326 and Validation Accuracy is 85.878906
# Time for epoch 85 is 0.000000 mins 27.000000 secs
#
# For Epoch 86, Training Loss is 0.043978 and Training Accuracy is 98.486328
# For Epoch 86, Validation Loss is 0.716176 and Validation Accuracy is 85.957031
# Time for epoch 86 is 0.000000 mins 27.000000 secs
#
# For Epoch 87, Training Loss is 0.042630 and Training Accuracy is 98.504577
# For Epoch 87, Validation Loss is 0.739522 and Validation Accuracy is 85.820312
# Time for epoch 87 is 0.000000 mins 28.000000 secs
#
# For Epoch 88, Training Loss is 0.045557 and Training Accuracy is 98.352421
# For Epoch 88, Validation Loss is 0.789928 and Validation Accuracy is 85.234375
# Time for epoch 88 is 0.000000 mins 27.000000 secs
#
# For Epoch 89, Training Loss is 0.041547 and Training Accuracy is 98.557844
# For Epoch 89, Validation Loss is 0.752474 and Validation Accuracy is 86.035156
# Time for epoch 89 is 0.000000 mins 28.000000 secs
#
# For Epoch 90, Training Loss is 0.046280 and Training Accuracy is 98.371409
# For Epoch 90, Validation Loss is 0.743537 and Validation Accuracy is 85.507812
# Time for epoch 90 is 0.000000 mins 28.000000 secs
#
# For Epoch 91, Training Loss is 0.039930 and Training Accuracy is 98.632812
# For Epoch 91, Validation Loss is 0.746326 and Validation Accuracy is 85.585938
# Time for epoch 91 is 0.000000 mins 28.000000 secs
#
# For Epoch 92, Training Loss is 0.038252 and Training Accuracy is 98.652788
# For Epoch 92, Validation Loss is 0.751224 and Validation Accuracy is 85.273438
# Time for epoch 92 is 0.000000 mins 28.000000 secs
#
# For Epoch 93, Training Loss is 0.037689 and Training Accuracy is 98.664378
# For Epoch 93, Validation Loss is 0.733675 and Validation Accuracy is 85.800781
# Time for epoch 93 is 0.000000 mins 28.000000 secs
#
# For Epoch 94, Training Loss is 0.036416 and Training Accuracy is 98.674982
# For Epoch 94, Validation Loss is 0.780449 and Validation Accuracy is 85.234375
# Time for epoch 94 is 0.000000 mins 28.000000 secs
#
# For Epoch 95, Training Loss is 0.039023 and Training Accuracy is 98.604946
# For Epoch 95, Validation Loss is 0.741334 and Validation Accuracy is 85.605469
# Time for epoch 95 is 0.000000 mins 28.000000 secs
#
# For Epoch 96, Training Loss is 0.041631 and Training Accuracy is 98.542801
# For Epoch 96, Validation Loss is 0.764828 and Validation Accuracy is 85.605469
# Time for epoch 96 is 0.000000 mins 27.000000 secs
#
# For Epoch 97, Training Loss is 0.037346 and Training Accuracy is 98.708274
# For Epoch 97, Validation Loss is 0.712945 and Validation Accuracy is 86.347656
# Time for epoch 97 is 0.000000 mins 28.000000 secs
#
# For Epoch 98, Training Loss is 0.035044 and Training Accuracy is 98.815301
# For Epoch 98, Validation Loss is 0.758544 and Validation Accuracy is 85.957031
# Time for epoch 98 is 0.000000 mins 28.000000 secs
#
# For Epoch 99, Training Loss is 0.033475 and Training Accuracy is 98.865856
# For Epoch 99, Validation Loss is 0.733321 and Validation Accuracy is 85.996094
# Time for epoch 99 is 0.000000 mins 28.000000 secs
#
# For Epoch 100, Training Loss is 0.033733 and Training Accuracy is 98.837003
# For Epoch 100, Validation Loss is 0.743759 and Validation Accuracy is 85.371094
# Time for epoch 100 is 0.000000 mins 28.000000 secs
#
# For Epoch 101, Training Loss is 0.037791 and Training Accuracy is 98.680408
# For Epoch 101, Validation Loss is 0.744285 and Validation Accuracy is 86.289062
# Time for epoch 101 is 0.000000 mins 28.000000 secs
#
# For Epoch 102, Training Loss is 0.035139 and Training Accuracy is 98.812589
# For Epoch 102, Validation Loss is 0.781445 and Validation Accuracy is 85.468750
# Time for epoch 102 is 0.000000 mins 28.000000 secs
#
# For Epoch 103, Training Loss is 0.035689 and Training Accuracy is 98.779297
# For Epoch 103, Validation Loss is 0.772630 and Validation Accuracy is 85.468750
# Time for epoch 103 is 0.000000 mins 28.000000 secs
#
# For Epoch 104, Training Loss is 0.036147 and Training Accuracy is 98.753157
# For Epoch 104, Validation Loss is 0.743929 and Validation Accuracy is 85.761719
# Time for epoch 104 is 0.000000 mins 28.000000 secs
#
# For Epoch 105, Training Loss is 0.034491 and Training Accuracy is 98.864623
# For Epoch 105, Validation Loss is 0.758196 and Validation Accuracy is 85.859375
# Time for epoch 105 is 0.000000 mins 28.000000 secs
#
# For Epoch 106, Training Loss is 0.031122 and Training Accuracy is 98.939591
# For Epoch 106, Validation Loss is 0.763585 and Validation Accuracy is 86.035156
# Time for epoch 106 is 0.000000 mins 28.000000 secs
#
# For Epoch 107, Training Loss is 0.030149 and Training Accuracy is 99.001736
# For Epoch 107, Validation Loss is 0.741385 and Validation Accuracy is 85.898438
# Time for epoch 107 is 0.000000 mins 28.000000 secs
#
# For Epoch 108, Training Loss is 0.029802 and Training Accuracy is 99.011107
# For Epoch 108, Validation Loss is 0.786142 and Validation Accuracy is 85.605469
# Time for epoch 108 is 0.000000 mins 28.000000 secs
#
# For Epoch 109, Training Loss is 0.028639 and Training Accuracy is 99.025657
# For Epoch 109, Validation Loss is 0.742508 and Validation Accuracy is 86.093750
# Time for epoch 109 is 0.000000 mins 28.000000 secs
#
# For Epoch 110, Training Loss is 0.031172 and Training Accuracy is 98.933426
# For Epoch 110, Validation Loss is 0.762632 and Validation Accuracy is 86.152344
# Time for epoch 110 is 0.000000 mins 28.000000 secs
#
# For Epoch 111, Training Loss is 0.030640 and Training Accuracy is 98.888544
# For Epoch 111, Validation Loss is 0.729808 and Validation Accuracy is 86.191406
# Time for epoch 111 is 0.000000 mins 27.000000 secs
#
# For Epoch 112, Training Loss is 0.030200 and Training Accuracy is 98.974609
# For Epoch 112, Validation Loss is 0.787040 and Validation Accuracy is 85.761719
# Time for epoch 112 is 0.000000 mins 28.000000 secs
#
# For Epoch 113, Training Loss is 0.029436 and Training Accuracy is 98.959566
# For Epoch 113, Validation Loss is 0.779322 and Validation Accuracy is 86.035156
# Time for epoch 113 is 0.000000 mins 28.000000 secs
#
# For Epoch 114, Training Loss is 0.031658 and Training Accuracy is 98.877446
# For Epoch 114, Validation Loss is 0.774644 and Validation Accuracy is 86.777344
# Time for epoch 114 is 0.000000 mins 28.000000 secs
#
# For Epoch 115, Training Loss is 0.031109 and Training Accuracy is 98.910245
# For Epoch 115, Validation Loss is 0.772290 and Validation Accuracy is 85.820312
# Time for epoch 115 is 0.000000 mins 28.000000 secs
#
# For Epoch 116, Training Loss is 0.027689 and Training Accuracy is 99.074978
# For Epoch 116, Validation Loss is 0.792329 and Validation Accuracy is 86.210938
# Time for epoch 116 is 0.000000 mins 28.000000 secs
#
# For Epoch 117, Training Loss is 0.026019 and Training Accuracy is 99.081143
# For Epoch 117, Validation Loss is 0.793770 and Validation Accuracy is 85.820312
# Time for epoch 117 is 0.000000 mins 28.000000 secs
#
# For Epoch 118, Training Loss is 0.026186 and Training Accuracy is 99.098899
# For Epoch 118, Validation Loss is 0.803148 and Validation Accuracy is 85.566406
# Time for epoch 118 is 0.000000 mins 28.000000 secs
#
# For Epoch 119, Training Loss is 0.025463 and Training Accuracy is 99.115422
# For Epoch 119, Validation Loss is 0.748839 and Validation Accuracy is 86.425781
# Time for epoch 119 is 0.000000 mins 28.000000 secs
#
# For Epoch 120, Training Loss is 0.024849 and Training Accuracy is 99.121094
# For Epoch 120, Validation Loss is 0.904723 and Validation Accuracy is 86.269531
# Time for epoch 120 is 0.000000 mins 28.000000 secs
#
# For Epoch 121, Training Loss is 0.026685 and Training Accuracy is 99.072759
# For Epoch 121, Validation Loss is 0.775140 and Validation Accuracy is 86.425781
# Time for epoch 121 is 0.000000 mins 28.000000 secs
#
# For Epoch 122, Training Loss is 0.027871 and Training Accuracy is 99.061168
# For Epoch 122, Validation Loss is 0.739637 and Validation Accuracy is 86.093750
# Time for epoch 122 is 0.000000 mins 28.000000 secs
#
# For Epoch 123, Training Loss is 0.027589 and Training Accuracy is 99.074978
# For Epoch 123, Validation Loss is 0.805572 and Validation Accuracy is 85.800781
# Time for epoch 123 is 0.000000 mins 28.000000 secs
#
# For Epoch 124, Training Loss is 0.024562 and Training Accuracy is 99.112216
# For Epoch 124, Validation Loss is 0.795756 and Validation Accuracy is 85.976562
# Time for epoch 124 is 0.000000 mins 28.000000 secs
#
# For Epoch 125, Training Loss is 0.025741 and Training Accuracy is 99.074978
# For Epoch 125, Validation Loss is 0.809364 and Validation Accuracy is 85.878906
# Time for epoch 125 is 0.000000 mins 28.000000 secs
#
# For Epoch 126, Training Loss is 0.026885 and Training Accuracy is 99.035028
# For Epoch 126, Validation Loss is 0.805034 and Validation Accuracy is 85.410156
# Time for epoch 126 is 0.000000 mins 28.000000 secs
#
# For Epoch 127, Training Loss is 0.023974 and Training Accuracy is 99.181019
# For Epoch 127, Validation Loss is 0.789197 and Validation Accuracy is 86.308594
# Time for epoch 127 is 0.000000 mins 28.000000 secs
#
# For Epoch 128, Training Loss is 0.024803 and Training Accuracy is 99.152166
# For Epoch 128, Validation Loss is 0.770180 and Validation Accuracy is 86.367188
# Time for epoch 128 is 0.000000 mins 28.000000 secs
#
# For Epoch 129, Training Loss is 0.025082 and Training Accuracy is 99.118134
# For Epoch 129, Validation Loss is 0.784613 and Validation Accuracy is 85.957031
# Time for epoch 129 is 0.000000 mins 28.000000 secs
#
# For Epoch 130, Training Loss is 0.023575 and Training Accuracy is 99.189897
# For Epoch 130, Validation Loss is 0.828726 and Validation Accuracy is 85.937500
# Time for epoch 130 is 0.000000 mins 27.000000 secs
#
# For Epoch 131, Training Loss is 0.021083 and Training Accuracy is 99.217024
# For Epoch 131, Validation Loss is 0.790229 and Validation Accuracy is 86.308594
# Time for epoch 131 is 0.000000 mins 28.000000 secs
#
# For Epoch 132, Training Loss is 0.024124 and Training Accuracy is 99.187678
# For Epoch 132, Validation Loss is 0.808307 and Validation Accuracy is 85.957031
# Time for epoch 132 is 0.000000 mins 28.000000 secs
#
# For Epoch 133, Training Loss is 0.023508 and Training Accuracy is 99.159318
# For Epoch 133, Validation Loss is 0.819270 and Validation Accuracy is 86.093750
# Time for epoch 133 is 0.000000 mins 27.000000 secs
#
# For Epoch 134, Training Loss is 0.024386 and Training Accuracy is 99.129972
# For Epoch 134, Validation Loss is 0.827011 and Validation Accuracy is 85.683594
# Time for epoch 134 is 0.000000 mins 27.000000 secs
#
# For Epoch 135, Training Loss is 0.024706 and Training Accuracy is 99.118874
# For Epoch 135, Validation Loss is 0.838516 and Validation Accuracy is 86.093750
# Time for epoch 135 is 0.000000 mins 28.000000 secs
#
# For Epoch 136, Training Loss is 0.023364 and Training Accuracy is 99.198775
# For Epoch 136, Validation Loss is 0.807347 and Validation Accuracy is 85.878906
# Time for epoch 136 is 0.000000 mins 28.000000 secs
#
# For Epoch 137, Training Loss is 0.021654 and Training Accuracy is 99.236999
# For Epoch 137, Validation Loss is 0.780189 and Validation Accuracy is 86.562500
# Time for epoch 137 is 0.000000 mins 27.000000 secs
#
# For Epoch 138, Training Loss is 0.022307 and Training Accuracy is 99.234779
# For Epoch 138, Validation Loss is 0.821323 and Validation Accuracy is 85.898438
# Time for epoch 138 is 0.000000 mins 28.000000 secs
#
# For Epoch 139, Training Loss is 0.024358 and Training Accuracy is 99.119368
# For Epoch 139, Validation Loss is 0.829132 and Validation Accuracy is 86.210938
# Time for epoch 139 is 0.000000 mins 28.000000 secs
#
# For Epoch 140, Training Loss is 0.024958 and Training Accuracy is 99.189897
# For Epoch 140, Validation Loss is 0.794911 and Validation Accuracy is 86.777344
# Time for epoch 140 is 0.000000 mins 28.000000 secs
#
# For Epoch 141, Training Loss is 0.020939 and Training Accuracy is 99.312461
# For Epoch 141, Validation Loss is 0.793943 and Validation Accuracy is 86.152344
# Time for epoch 141 is 0.000000 mins 28.000000 secs
#
# For Epoch 142, Training Loss is 0.018619 and Training Accuracy is 99.383483
# For Epoch 142, Validation Loss is 0.766319 and Validation Accuracy is 86.308594
# Time for epoch 142 is 0.000000 mins 27.000000 secs
#
# For Epoch 143, Training Loss is 0.018487 and Training Accuracy is 99.360795
# For Epoch 143, Validation Loss is 0.842119 and Validation Accuracy is 85.683594
# Time for epoch 143 is 0.000000 mins 28.000000 secs
#
# For Epoch 144, Training Loss is 0.022163 and Training Accuracy is 99.232067
# For Epoch 144, Validation Loss is 0.816583 and Validation Accuracy is 86.113281
# Time for epoch 144 is 0.000000 mins 28.000000 secs
#
# For Epoch 145, Training Loss is 0.020265 and Training Accuracy is 99.270291
# For Epoch 145, Validation Loss is 0.796384 and Validation Accuracy is 86.875000
# Time for epoch 145 is 0.000000 mins 28.000000 secs
#
# For Epoch 146, Training Loss is 0.018713 and Training Accuracy is 99.314187
# For Epoch 146, Validation Loss is 0.795685 and Validation Accuracy is 86.503906
# Time for epoch 146 is 0.000000 mins 28.000000 secs
#
# For Epoch 147, Training Loss is 0.020394 and Training Accuracy is 99.285334
# For Epoch 147, Validation Loss is 0.847932 and Validation Accuracy is 85.605469
# Time for epoch 147 is 0.000000 mins 28.000000 secs
#
# For Epoch 148, Training Loss is 0.021050 and Training Accuracy is 99.229847
# For Epoch 148, Validation Loss is 0.841583 and Validation Accuracy is 85.976562
# Time for epoch 148 is 0.000000 mins 28.000000 secs
#
# For Epoch 149, Training Loss is 0.020615 and Training Accuracy is 99.325777
# For Epoch 149, Validation Loss is 0.824605 and Validation Accuracy is 86.425781
# Time for epoch 149 is 0.000000 mins 28.000000 secs
#
# For Epoch 150, Training Loss is 0.022044 and Training Accuracy is 99.207653
# For Epoch 150, Validation Loss is 0.809182 and Validation Accuracy is 86.347656
# Time for epoch 150 is 0.000000 mins 28.000000 secs
#
# For Epoch 151, Training Loss is 0.022207 and Training Accuracy is 99.240945
# For Epoch 151, Validation Loss is 0.800037 and Validation Accuracy is 86.738281
# Time for epoch 151 is 0.000000 mins 27.000000 secs
#
# For Epoch 152, Training Loss is 0.018070 and Training Accuracy is 99.389648
# For Epoch 152, Validation Loss is 0.783182 and Validation Accuracy is 87.226562
# Time for epoch 152 is 0.000000 mins 28.000000 secs
#
# For Epoch 153, Training Loss is 0.019508 and Training Accuracy is 99.305309
# For Epoch 153, Validation Loss is 0.825946 and Validation Accuracy is 86.464844
# Time for epoch 153 is 0.000000 mins 27.000000 secs
#
# For Epoch 154, Training Loss is 0.018612 and Training Accuracy is 99.367454
# For Epoch 154, Validation Loss is 0.901823 and Validation Accuracy is 85.859375
# Time for epoch 154 is 0.000000 mins 27.000000 secs
#
# For Epoch 155, Training Loss is 0.017597 and Training Accuracy is 99.385210
# For Epoch 155, Validation Loss is 0.833021 and Validation Accuracy is 86.054688
# Time for epoch 155 is 0.000000 mins 28.000000 secs
#
# For Epoch 156, Training Loss is 0.018470 and Training Accuracy is 99.374112
# For Epoch 156, Validation Loss is 0.851889 and Validation Accuracy is 85.917969
# Time for epoch 156 is 0.000000 mins 27.000000 secs
#
# For Epoch 157, Training Loss is 0.020267 and Training Accuracy is 99.305802
# For Epoch 157, Validation Loss is 0.804059 and Validation Accuracy is 86.757812
# Time for epoch 157 is 0.000000 mins 27.000000 secs
#
# For Epoch 158, Training Loss is 0.018520 and Training Accuracy is 99.356850
# For Epoch 158, Validation Loss is 0.800489 and Validation Accuracy is 86.562500
# Time for epoch 158 is 0.000000 mins 28.000000 secs
#
# For Epoch 159, Training Loss is 0.019656 and Training Accuracy is 99.294212
# For Epoch 159, Validation Loss is 0.827653 and Validation Accuracy is 86.445312
# Time for epoch 159 is 0.000000 mins 28.000000 secs
#
# For Epoch 160, Training Loss is 0.018992 and Training Accuracy is 99.325777
# For Epoch 160, Validation Loss is 0.803344 and Validation Accuracy is 86.621094
# Time for epoch 160 is 0.000000 mins 28.000000 secs
#
# For Epoch 161, Training Loss is 0.018859 and Training Accuracy is 99.319119
# For Epoch 161, Validation Loss is 0.788706 and Validation Accuracy is 86.816406
# Time for epoch 161 is 0.000000 mins 28.000000 secs
#
# For Epoch 162, Training Loss is 0.016902 and Training Accuracy is 99.387429
# For Epoch 162, Validation Loss is 0.849531 and Validation Accuracy is 85.859375
# Time for epoch 162 is 0.000000 mins 27.000000 secs
#
# For Epoch 163, Training Loss is 0.017794 and Training Accuracy is 99.359562
# For Epoch 163, Validation Loss is 0.833742 and Validation Accuracy is 86.640625
# Time for epoch 163 is 0.000000 mins 27.000000 secs
#
# For Epoch 164, Training Loss is 0.018230 and Training Accuracy is 99.383976
# For Epoch 164, Validation Loss is 0.866558 and Validation Accuracy is 85.644531
# Time for epoch 164 is 0.000000 mins 28.000000 secs
#
# For Epoch 165, Training Loss is 0.018336 and Training Accuracy is 99.363015
# For Epoch 165, Validation Loss is 0.815386 and Validation Accuracy is 86.132812
# Time for epoch 165 is 0.000000 mins 28.000000 secs
#
# For Epoch 166, Training Loss is 0.018905 and Training Accuracy is 99.376332
# For Epoch 166, Validation Loss is 0.805089 and Validation Accuracy is 86.660156
# Time for epoch 166 is 0.000000 mins 28.000000 secs
#
# For Epoch 167, Training Loss is 0.015843 and Training Accuracy is 99.473988
# For Epoch 167, Validation Loss is 0.818955 and Validation Accuracy is 86.621094
# Time for epoch 167 is 0.000000 mins 28.000000 secs
#
# For Epoch 168, Training Loss is 0.015545 and Training Accuracy is 99.465110
# For Epoch 168, Validation Loss is 0.826643 and Validation Accuracy is 86.992188
# Time for epoch 168 is 0.000000 mins 28.000000 secs
#
# For Epoch 169, Training Loss is 0.017488 and Training Accuracy is 99.410117
# For Epoch 169, Validation Loss is 0.847566 and Validation Accuracy is 86.171875
# Time for epoch 169 is 0.000000 mins 29.000000 secs
#
# For Epoch 170, Training Loss is 0.015515 and Training Accuracy is 99.469549
# For Epoch 170, Validation Loss is 0.930016 and Validation Accuracy is 85.859375
# Time for epoch 170 is 0.000000 mins 28.000000 secs
#
# For Epoch 171, Training Loss is 0.015602 and Training Accuracy is 99.430092
# For Epoch 171, Validation Loss is 0.853498 and Validation Accuracy is 86.308594
# Time for epoch 171 is 0.000000 mins 28.000000 secs
#
# For Epoch 172, Training Loss is 0.017358 and Training Accuracy is 99.418995
# For Epoch 172, Validation Loss is 0.837161 and Validation Accuracy is 86.777344
# Time for epoch 172 is 0.000000 mins 28.000000 secs
#
# For Epoch 173, Training Loss is 0.015128 and Training Accuracy is 99.498402
# For Epoch 173, Validation Loss is 0.840952 and Validation Accuracy is 86.757812
# Time for epoch 173 is 0.000000 mins 28.000000 secs
#
# For Epoch 174, Training Loss is 0.014555 and Training Accuracy is 99.505060
# For Epoch 174, Validation Loss is 0.835791 and Validation Accuracy is 86.054688
# Time for epoch 174 is 0.000000 mins 28.000000 secs
#
# For Epoch 175, Training Loss is 0.016947 and Training Accuracy is 99.422940
# For Epoch 175, Validation Loss is 0.809971 and Validation Accuracy is 86.425781
# Time for epoch 175 is 0.000000 mins 28.000000 secs
#
# For Epoch 176, Training Loss is 0.016782 and Training Accuracy is 99.418501
# For Epoch 176, Validation Loss is 0.830297 and Validation Accuracy is 86.113281
# Time for epoch 176 is 0.000000 mins 28.000000 secs
#
# For Epoch 177, Training Loss is 0.019544 and Training Accuracy is 99.330216
# For Epoch 177, Validation Loss is 0.803051 and Validation Accuracy is 86.660156
# Time for epoch 177 is 0.000000 mins 28.000000 secs
#
# For Epoch 178, Training Loss is 0.015595 and Training Accuracy is 99.454013
# For Epoch 178, Validation Loss is 0.806793 and Validation Accuracy is 86.816406
# Time for epoch 178 is 0.000000 mins 28.000000 secs
#
# For Epoch 179, Training Loss is 0.013324 and Training Accuracy is 99.538352
# For Epoch 179, Validation Loss is 0.819069 and Validation Accuracy is 86.718750
# Time for epoch 179 is 0.000000 mins 28.000000 secs
#
# For Epoch 180, Training Loss is 0.014761 and Training Accuracy is 99.475468
# For Epoch 180, Validation Loss is 0.826940 and Validation Accuracy is 86.210938
# Time for epoch 180 is 0.000000 mins 28.000000 secs
#
# For Epoch 181, Training Loss is 0.014778 and Training Accuracy is 99.445135
# For Epoch 181, Validation Loss is 0.820356 and Validation Accuracy is 87.187500
# Time for epoch 181 is 0.000000 mins 28.000000 secs
#
# For Epoch 182, Training Loss is 0.016700 and Training Accuracy is 99.425653
# For Epoch 182, Validation Loss is 0.841654 and Validation Accuracy is 86.152344
# Time for epoch 182 is 0.000000 mins 28.000000 secs
#
# For Epoch 183, Training Loss is 0.012538 and Training Accuracy is 99.562766
# For Epoch 183, Validation Loss is 0.842393 and Validation Accuracy is 86.250000
# Time for epoch 183 is 0.000000 mins 29.000000 secs
#
# For Epoch 184, Training Loss is 0.013056 and Training Accuracy is 99.536133
# For Epoch 184, Validation Loss is 0.841195 and Validation Accuracy is 86.640625
# Time for epoch 184 is 0.000000 mins 28.000000 secs
#
# For Epoch 185, Training Loss is 0.011506 and Training Accuracy is 99.607156
# For Epoch 185, Validation Loss is 0.884100 and Validation Accuracy is 86.347656
# Time for epoch 185 is 0.000000 mins 28.000000 secs
#
# For Epoch 186, Training Loss is 0.014905 and Training Accuracy is 99.465110
# For Epoch 186, Validation Loss is 0.879904 and Validation Accuracy is 85.898438
# Time for epoch 186 is 0.000000 mins 28.000000 secs
#
# For Epoch 187, Training Loss is 0.014393 and Training Accuracy is 99.498402
# For Epoch 187, Validation Loss is 0.839548 and Validation Accuracy is 86.015625
# Time for epoch 187 is 0.000000 mins 29.000000 secs
#
# For Epoch 188, Training Loss is 0.012495 and Training Accuracy is 99.582741
# For Epoch 188, Validation Loss is 0.814046 and Validation Accuracy is 86.933594
# Time for epoch 188 is 0.000000 mins 28.000000 secs
#
# For Epoch 189, Training Loss is 0.013267 and Training Accuracy is 99.600497
# For Epoch 189, Validation Loss is 0.827612 and Validation Accuracy is 86.894531
# Time for epoch 189 is 0.000000 mins 28.000000 secs
#
# For Epoch 190, Training Loss is 0.013799 and Training Accuracy is 99.525036
# For Epoch 190, Validation Loss is 0.857226 and Validation Accuracy is 86.445312
# Time for epoch 190 is 0.000000 mins 28.000000 secs
#
# For Epoch 191, Training Loss is 0.011742 and Training Accuracy is 99.609375
# For Epoch 191, Validation Loss is 0.884422 and Validation Accuracy is 85.898438
# Time for epoch 191 is 0.000000 mins 27.000000 secs
#
# For Epoch 192, Training Loss is 0.013519 and Training Accuracy is 99.556601
# For Epoch 192, Validation Loss is 0.834886 and Validation Accuracy is 86.406250
# Time for epoch 192 is 0.000000 mins 28.000000 secs
#
# For Epoch 193, Training Loss is 0.016059 and Training Accuracy is 99.412336
# For Epoch 193, Validation Loss is 0.897530 and Validation Accuracy is 85.996094
# Time for epoch 193 is 0.000000 mins 28.000000 secs
#
# For Epoch 194, Training Loss is 0.014350 and Training Accuracy is 99.529474
# For Epoch 194, Validation Loss is 0.823081 and Validation Accuracy is 86.503906
# Time for epoch 194 is 0.000000 mins 28.000000 secs
#
# For Epoch 195, Training Loss is 0.012384 and Training Accuracy is 99.556601
# For Epoch 195, Validation Loss is 0.827796 and Validation Accuracy is 86.210938
# Time for epoch 195 is 0.000000 mins 28.000000 secs
#
# For Epoch 196, Training Loss is 0.014113 and Training Accuracy is 99.511719
# For Epoch 196, Validation Loss is 0.840454 and Validation Accuracy is 86.523438
# Time for epoch 196 is 0.000000 mins 28.000000 secs
#
# For Epoch 197, Training Loss is 0.014689 and Training Accuracy is 99.485085
# For Epoch 197, Validation Loss is 0.875945 and Validation Accuracy is 86.035156
# Time for epoch 197 is 0.000000 mins 28.000000 secs
#
# For Epoch 198, Training Loss is 0.012743 and Training Accuracy is 99.573864
# For Epoch 198, Validation Loss is 0.865914 and Validation Accuracy is 86.621094
# Time for epoch 198 is 0.000000 mins 28.000000 secs
#
# For Epoch 199, Training Loss is 0.013394 and Training Accuracy is 99.542791
# For Epoch 199, Validation Loss is 0.846155 and Validation Accuracy is 86.718750
# Time for epoch 199 is 0.000000 mins 28.000000 secs
#
# For Epoch 200, Training Loss is 0.011231 and Training Accuracy is 99.636009
# For Epoch 200, Validation Loss is 0.866378 and Validation Accuracy is 86.386719
# Time for epoch 200 is 0.000000 mins 27.000000 secs

# %%
def get_predictions(model, iterator, device):
    # model.load_state_dict(torch.load("/content/best_model")) 
    # model.optimizer=optimizer
    model.eval()

    labels = []
    probs = []
    

    for x,y in iterator:
      x = x.to(device)
      y = y.to(device)
      
      y_pred = model(x)
      labels.append(y)
      probs.append(y_pred)


    #Converting the labels and probabilities obtained to a tensor
    labels = torch.cat(labels, dim = 0)
    probs = torch.cat(probs, dim = 0)

    return labels, probs

# %%
resnet18.load_state_dict(torch.load('/content/best_model.pt'))
resnet18.optimizer = optimizer

labels, probs = get_predictions(resnet18, test_iterator, device)

print("Accuracy on Test Data is %f%%" %(calculate_accuracy(probs, labels).to('cpu').detach().numpy()*100))
# Out:
# Accuracy on Test Data is 86.439997%

# %%
train_loss_list
