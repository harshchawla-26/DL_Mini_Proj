# %%
from psutil import virtual_memory
ram_gb = virtual_memory().total / 1e9
print('Your runtime has {:.1f} gigabytes of available RAM\n'.format(ram_gb))
# Out:
# Your runtime has 13.6 gigabytes of available RAM

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.optim.lr_scheduler import _LRScheduler
import torch.utils.data as data

import torchvision.transforms as transforms
import torchvision.datasets as datasets

from sklearn import decomposition
from sklearn import manifold
from sklearn.metrics import confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay
import matplotlib.pyplot as plt
import numpy as np

import copy
import random
import time

# %%
SEED = 1234

random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
torch.cuda.manual_seed(SEED)
torch.backends.cudnn.deterministic = True

# %%
ROOT = '.data'
train_data = datasets.CIFAR10(root = ROOT, 
                              train = True, 
                              download = True)
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to .data/cifar-10-python.tar.gz
#   0%|          | 0/170498071 [00:00<?, ?it/s]
# Extracting .data/cifar-10-python.tar.gz to .data

# %%
means = train_data.data.mean(axis = (0,1,2)) / 255
stds = train_data.data.std(axis = (0,1,2)) / 255

# %%
train_transforms = transforms.Compose([
                           transforms.RandomRotation(5),
                           transforms.RandomHorizontalFlip(0.5),
                           transforms.RandomCrop(32, padding = 2),
                           transforms.ToTensor(),
                           transforms.Normalize(mean = means, 
                                                std = stds)
                       ])

test_transforms = transforms.Compose([
                           transforms.ToTensor(),
                           transforms.Normalize(mean = means, 
                                                std = stds)
                       ])

# %%
train_data = datasets.CIFAR10(ROOT, 
                              train = True, 
                              download = True, 
                              transform = train_transforms)

test_data = datasets.CIFAR10(ROOT, 
                             train = False, 
                             download = True, 
                             transform = test_transforms)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
VALID_RATIO = 0.9

n_train_examples = int(len(train_data) * VALID_RATIO)
n_valid_examples = len(train_data) - n_train_examples

train_data, valid_data = data.random_split(train_data, 
                                           [n_train_examples, n_valid_examples])

# %%
BATCH_SIZE =16

train_iterator = torch.utils.data.DataLoader(train_data, BATCH_SIZE, shuffle = True)

valid_iterator = torch.utils.data.DataLoader(valid_data, BATCH_SIZE, shuffle = True)

test_iterator = torch.utils.data.DataLoader(test_data, BATCH_SIZE, shuffle = True)

# %%
class ResBlock(nn.Module):
    def __init__(self, in_channels, out_channels, downsample):
        super().__init__()
        if downsample:
            self.conv1 = nn.Conv2d(
                in_channels, out_channels, kernel_size=3, stride=2, padding=1)
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_channels, out_channels, kernel_size=1, stride=2),
                nn.BatchNorm2d(out_channels)
            )
        else:
            self.conv1 = nn.Conv2d(
                in_channels, out_channels, kernel_size=3, stride=1, padding=1)
            self.shortcut = nn.Sequential()

        self.conv2 = nn.Conv2d(out_channels, out_channels,
                               kernel_size=3, stride=1, padding=1)
        self.bn1 = nn.BatchNorm2d(out_channels)
        self.bn2 = nn.BatchNorm2d(out_channels)

    def forward(self, input):
        shortcut = self.shortcut(input)
        input = nn.ReLU()(self.bn1(self.conv1(input)))
        input = nn.ReLU()(self.bn2(self.conv2(input)))
        input = input + shortcut
        return nn.ReLU()(input)

# %%
class ResNet(nn.Module):
    def __init__(self, in_channels, resblock, repeat, useBottleneck=False, outputs=10):
        super().__init__()
        self.layer0 = nn.Sequential(
            nn.Conv2d(in_channels, 64, kernel_size=7, stride=1, padding=1),
            nn.MaxPool2d(kernel_size=3, stride=2, padding=1),
            nn.BatchNorm2d(64),
            nn.ReLU()
        )

        if useBottleneck:
            filters = [64, 256, 512, 1024, 2048]
        else:
            filters = [64, 64, 128, 256, 242]

        self.layer1 = nn.Sequential()
        self.layer1.add_module('conv2_1', resblock(filters[0], filters[1], downsample=False))
        for i in range(1, repeat[0]):
                self.layer1.add_module('conv2_%d'%(i+1,), resblock(filters[1], filters[1], downsample=False))

        self.layer2 = nn.Sequential()
        self.layer2.add_module('conv3_1', resblock(filters[1], filters[2], downsample=True))
        for i in range(1, repeat[1]):
                self.layer2.add_module('conv3_%d' % (
                    i+1,), resblock(filters[2], filters[2], downsample=False))

        self.layer3 = nn.Sequential()
        self.layer3.add_module('conv4_1', resblock(filters[2], filters[3], downsample=True))
        for i in range(1, repeat[2]):
            self.layer3.add_module('conv2_%d' % (
                i+1,), resblock(filters[3], filters[3], downsample=False))

        self.layer4 = nn.Sequential()
        self.layer4.add_module('conv5_1', resblock(filters[3], filters[4], downsample=True))
        for i in range(1, repeat[3]):
            self.layer4.add_module('conv3_%d'%(i+1,),resblock(filters[4], filters[4], downsample=False))

        self.gap = torch.nn.AdaptiveAvgPool2d(1)
        self.fc = torch.nn.Linear(filters[4], outputs)

    def forward(self, input):
        input = self.layer0(input)
        input = self.layer1(input)
        input = self.layer2(input)
        input = self.layer3(input)
        input = self.layer4(input)
        input = self.gap(input)
        # torch.flatten()
        # https://stackoverflow.com/questions/60115633/pytorch-flatten-doesnt-maintain-batch-size
        input = torch.flatten(input, start_dim=1)
        input = self.fc(input)

        return input

# %%
from torchsummary import summary



resnet18 = ResNet(3, ResBlock, [2, 2, 2, 2], useBottleneck=False, outputs=10)
resnet18.to(torch.device("cuda:0" if torch.cuda.is_available() else "cpu"))
summary(resnet18, (3, 32, 32))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 64, 28, 28]           9,472
#          MaxPool2d-2           [-1, 64, 14, 14]               0
#        BatchNorm2d-3           [-1, 64, 14, 14]             128
#               ReLU-4           [-1, 64, 14, 14]               0
#             Conv2d-5           [-1, 64, 14, 14]          36,928
#        BatchNorm2d-6           [-1, 64, 14, 14]             128
#             Conv2d-7           [-1, 64, 14, 14]          36,928
#        BatchNorm2d-8           [-1, 64, 14, 14]             128
#           ResBlock-9           [-1, 64, 14, 14]               0
#            Conv2d-10           [-1, 64, 14, 14]          36,928
#       BatchNorm2d-11           [-1, 64, 14, 14]             128
#            Conv2d-12           [-1, 64, 14, 14]          36,928
#       BatchNorm2d-13           [-1, 64, 14, 14]             128
#          ResBlock-14           [-1, 64, 14, 14]               0
#            Conv2d-15            [-1, 128, 7, 7]           8,320
#       BatchNorm2d-16            [-1, 128, 7, 7]             256
#            Conv2d-17            [-1, 128, 7, 7]          73,856
#       BatchNorm2d-18            [-1, 128, 7, 7]             256
#            Conv2d-19            [-1, 128, 7, 7]         147,584
#       BatchNorm2d-20            [-1, 128, 7, 7]             256
#          ResBlock-21            [-1, 128, 7, 7]               0
#            Conv2d-22            [-1, 128, 7, 7]         147,584
#       BatchNorm2d-23            [-1, 128, 7, 7]             256
#            Conv2d-24            [-1, 128, 7, 7]         147,584
#       BatchNorm2d-25            [-1, 128, 7, 7]             256
#          ResBlock-26            [-1, 128, 7, 7]               0
#            Conv2d-27            [-1, 256, 4, 4]          33,024
#       BatchNorm2d-28            [-1, 256, 4, 4]             512
#            Conv2d-29            [-1, 256, 4, 4]         295,168
#       BatchNorm2d-30            [-1, 256, 4, 4]             512
#            Conv2d-31            [-1, 256, 4, 4]         590,080
#       BatchNorm2d-32            [-1, 256, 4, 4]             512
#          ResBlock-33            [-1, 256, 4, 4]               0
#            Conv2d-34            [-1, 256, 4, 4]         590,080
#       BatchNorm2d-35            [-1, 256, 4, 4]             512
#            Conv2d-36            [-1, 256, 4, 4]         590,080
#       BatchNorm2d-37            [-1, 256, 4, 4]             512
#          ResBlock-38            [-1, 256, 4, 4]               0
#            Conv2d-39            [-1, 242, 2, 2]          62,194
#       BatchNorm2d-40            [-1, 242, 2, 2]             484
#            Conv2d-41            [-1, 242, 2, 2]         557,810
#       BatchNorm2d-42            [-1, 242, 2, 2]             484
#            Conv2d-43            [-1, 242, 2, 2]         527,318
#       BatchNorm2d-44            [-1, 242, 2, 2]             484
#          ResBlock-45            [-1, 242, 2, 2]               0
#            Conv2d-46            [-1, 242, 2, 2]         527,318
#       BatchNorm2d-47            [-1, 242, 2, 2]             484
#            Conv2d-48            [-1, 242, 2, 2]         527,318
#       BatchNorm2d-49            [-1, 242, 2, 2]             484
#          ResBlock-50            [-1, 242, 2, 2]               0
# AdaptiveAvgPool2d-51            [-1, 242, 1, 1]               0
#            Linear-52                   [-1, 10]           2,430
# ================================================================
# Total params: 4,991,832
# Trainable params: 4,991,832
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 2.67
# Params size (MB): 19.04
# Estimated Total Size (MB): 21.72
# ----------------------------------------------------------------

# %%
optimizer = optim.SGD(resnet18.parameters(), lr=0.01, momentum=0.9)
# optimizer = optim.Adam(resnet18.parameters(), lr = 1e-3)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
criterion = nn.CrossEntropyLoss()

criterion = criterion.to(device)

# %%
def calculate_accuracy(y_pred, y):
    top_pred = y_pred.argmax(1, keepdim = True)
    correct = top_pred.eq(y.view_as(top_pred)).sum()
    acc = correct.float() / y.shape[0]
    return acc

# %%
def train(model, iterator, optimizer, criterion, device):
    
    epoch_loss = 0
    epoch_acc = 0
    
    model.train()
    
    for (x, y) in iterator:
        
        x = x.to(device)
        y = y.to(device)
        
        optimizer.zero_grad()
                
        y_pred = model(x)
        
        loss = criterion(y_pred, y)
        
        acc = calculate_accuracy(y_pred, y)
        
        loss.backward()
        
        optimizer.step()
        
        epoch_loss += loss.item()
        epoch_acc += acc.item()
        
    return epoch_loss / len(iterator), epoch_acc / len(iterator)

# %%
def evaluate(model, iterator, criterion, device):
    
    epoch_loss = 0
    epoch_acc = 0
    
    model.eval()
    
    with torch.no_grad():
        
        for (x, y) in iterator:

            x = x.to(device)
            y = y.to(device)

            y_pred = model(x)

            loss = criterion(y_pred, y)

            acc = calculate_accuracy(y_pred, y)

            epoch_loss += loss.item()
            epoch_acc += acc.item()
        
    return epoch_loss / len(iterator), epoch_acc / len(iterator)

# %%
def epoch_time(start_time, end_time):
    elapsed_time = end_time - start_time
    elapsed_mins = int(elapsed_time / 60)
    elapsed_secs = int(elapsed_time - (elapsed_mins * 60))
    return elapsed_mins, elapsed_secs

# %%
import math
import time

EPOCHS = 100

#Setting a min variable to store model with minimum loss and then store that model
min = math.inf
for e in range(EPOCHS):
  start_time = time.time()
  train_loss, train_accuracy = train(resnet18, train_iterator, optimizer, criterion, device)
  valid_loss, valid_accuracy = evaluate(resnet18, valid_iterator, criterion, device)
  print("For Epoch %d, Training Loss is %f and Training Accuracy is %f" %(e+1, train_loss, train_accuracy*100))
  print("For Epoch %d, Validation Loss is %f and Validation Accuracy is %f" %(e+1, valid_loss, valid_accuracy*100))
  #using torch.save() to store the best model i.e. the one with minimum validation loss
  if valid_loss < min:
    # torch.save(resnet18, 'best_model')
    torch.save(resnet18.state_dict(),"/content/best_model.pt")
  end_time = time.time()
  elapsed_mins, elapsed_secs = epoch_time(start_time, end_time)
  print("Time for epoch %d is %f mins %f secs \n" % (e+1, elapsed_mins, elapsed_secs))
# Out:
# For Epoch 1, Training Loss is 1.624351 and Training Accuracy is 41.361536
# For Epoch 1, Validation Loss is 1.276394 and Validation Accuracy is 54.912141
# Time for epoch 1 is 1.000000 mins 9.000000 secs
#
# For Epoch 2, Training Loss is 1.190405 and Training Accuracy is 57.914149
# For Epoch 2, Validation Loss is 1.036205 and Validation Accuracy is 63.338658
# Time for epoch 2 is 1.000000 mins 8.000000 secs
#
# For Epoch 3, Training Loss is 0.975760 and Training Accuracy is 65.959385
# For Epoch 3, Validation Loss is 0.841853 and Validation Accuracy is 70.567093
# Time for epoch 3 is 1.000000 mins 8.000000 secs
#
# For Epoch 4, Training Loss is 0.846640 and Training Accuracy is 70.494134
# For Epoch 4, Validation Loss is 0.768051 and Validation Accuracy is 73.462460
# Time for epoch 4 is 1.000000 mins 9.000000 secs
#
# For Epoch 5, Training Loss is 0.755466 and Training Accuracy is 73.722449
# For Epoch 5, Validation Loss is 0.734512 and Validation Accuracy is 74.261182
# Time for epoch 5 is 1.000000 mins 9.000000 secs
#
# For Epoch 6, Training Loss is 0.679941 and Training Accuracy is 76.264220
# For Epoch 6, Validation Loss is 0.658285 and Validation Accuracy is 77.196486
# Time for epoch 6 is 1.000000 mins 9.000000 secs
#
# For Epoch 7, Training Loss is 0.633284 and Training Accuracy is 77.928368
# For Epoch 7, Validation Loss is 0.675223 and Validation Accuracy is 76.876997
# Time for epoch 7 is 1.000000 mins 8.000000 secs
#
# For Epoch 8, Training Loss is 0.582431 and Training Accuracy is 79.754710
# For Epoch 8, Validation Loss is 0.595316 and Validation Accuracy is 79.712460
# Time for epoch 8 is 1.000000 mins 7.000000 secs
#
# For Epoch 9, Training Loss is 0.548281 and Training Accuracy is 80.981159
# For Epoch 9, Validation Loss is 0.570162 and Validation Accuracy is 80.151757
# Time for epoch 9 is 1.000000 mins 7.000000 secs
#
# For Epoch 10, Training Loss is 0.516080 and Training Accuracy is 82.096516
# For Epoch 10, Validation Loss is 0.562508 and Validation Accuracy is 81.030351
# Time for epoch 10 is 1.000000 mins 8.000000 secs
#
# For Epoch 11, Training Loss is 0.480092 and Training Accuracy is 83.360736
# For Epoch 11, Validation Loss is 0.596362 and Validation Accuracy is 79.972045
# Time for epoch 11 is 1.000000 mins 8.000000 secs
#
# For Epoch 12, Training Loss is 0.457706 and Training Accuracy is 83.965073
# For Epoch 12, Validation Loss is 0.558745 and Validation Accuracy is 81.070288
# Time for epoch 12 is 1.000000 mins 8.000000 secs
#
# For Epoch 13, Training Loss is 0.434718 and Training Accuracy is 84.860469
# For Epoch 13, Validation Loss is 0.547153 and Validation Accuracy is 81.869010
# Time for epoch 13 is 1.000000 mins 6.000000 secs
#
# For Epoch 14, Training Loss is 0.407410 and Training Accuracy is 85.855848
# For Epoch 14, Validation Loss is 0.547767 and Validation Accuracy is 81.509585
# Time for epoch 14 is 1.000000 mins 7.000000 secs
#
# For Epoch 15, Training Loss is 0.393446 and Training Accuracy is 86.433523
# For Epoch 15, Validation Loss is 0.526340 and Validation Accuracy is 82.448083
# Time for epoch 15 is 1.000000 mins 8.000000 secs
#
# For Epoch 16, Training Loss is 0.373829 and Training Accuracy is 87.071187
# For Epoch 16, Validation Loss is 0.521180 and Validation Accuracy is 82.767572
# Time for epoch 16 is 1.000000 mins 8.000000 secs
#
# For Epoch 17, Training Loss is 0.357578 and Training Accuracy is 87.433345
# For Epoch 17, Validation Loss is 0.490054 and Validation Accuracy is 83.506390
# Time for epoch 17 is 1.000000 mins 8.000000 secs
#
# For Epoch 18, Training Loss is 0.338491 and Training Accuracy is 88.173214
# For Epoch 18, Validation Loss is 0.520647 and Validation Accuracy is 82.667732
# Time for epoch 18 is 1.000000 mins 7.000000 secs
#
# For Epoch 19, Training Loss is 0.320006 and Training Accuracy is 88.755332
# For Epoch 19, Validation Loss is 0.487268 and Validation Accuracy is 84.624601
# Time for epoch 19 is 1.000000 mins 7.000000 secs
#
# For Epoch 20, Training Loss is 0.309279 and Training Accuracy is 89.028617
# For Epoch 20, Validation Loss is 0.515967 and Validation Accuracy is 83.007188
# Time for epoch 20 is 1.000000 mins 7.000000 secs
#
# For Epoch 21, Training Loss is 0.298903 and Training Accuracy is 89.504088
# For Epoch 21, Validation Loss is 0.487080 and Validation Accuracy is 84.145367
# Time for epoch 21 is 1.000000 mins 7.000000 secs
#
# For Epoch 22, Training Loss is 0.285106 and Training Accuracy is 90.237291
# For Epoch 22, Validation Loss is 0.507474 and Validation Accuracy is 83.486422
# Time for epoch 22 is 1.000000 mins 8.000000 secs
#
# For Epoch 23, Training Loss is 0.270639 and Training Accuracy is 90.503910
# For Epoch 23, Validation Loss is 0.487930 and Validation Accuracy is 84.325080
# Time for epoch 23 is 1.000000 mins 6.000000 secs
#
# For Epoch 24, Training Loss is 0.259447 and Training Accuracy is 90.946054
# For Epoch 24, Validation Loss is 0.476712 and Validation Accuracy is 85.063898
# Time for epoch 24 is 1.000000 mins 7.000000 secs
#
# For Epoch 25, Training Loss is 0.247421 and Training Accuracy is 91.226004
# For Epoch 25, Validation Loss is 0.446600 and Validation Accuracy is 85.583067
# Time for epoch 25 is 1.000000 mins 6.000000 secs
#
# For Epoch 26, Training Loss is 0.233841 and Training Accuracy is 91.710363
# For Epoch 26, Validation Loss is 0.468987 and Validation Accuracy is 85.323482
# Time for epoch 26 is 1.000000 mins 6.000000 secs
#
# For Epoch 27, Training Loss is 0.229430 and Training Accuracy is 91.939211
# For Epoch 27, Validation Loss is 0.476907 and Validation Accuracy is 85.063898
# Time for epoch 27 is 1.000000 mins 7.000000 secs
#
# For Epoch 28, Training Loss is 0.217999 and Training Accuracy is 92.539104
# For Epoch 28, Validation Loss is 0.499125 and Validation Accuracy is 84.944089
# Time for epoch 28 is 1.000000 mins 7.000000 secs
#
# For Epoch 29, Training Loss is 0.211624 and Training Accuracy is 92.512442
# For Epoch 29, Validation Loss is 0.493187 and Validation Accuracy is 84.844249
# Time for epoch 29 is 1.000000 mins 7.000000 secs
#
# For Epoch 30, Training Loss is 0.204451 and Training Accuracy is 92.783505
# For Epoch 30, Validation Loss is 0.468933 and Validation Accuracy is 85.882588
# Time for epoch 30 is 1.000000 mins 6.000000 secs
#
# For Epoch 31, Training Loss is 0.194732 and Training Accuracy is 93.167881
# For Epoch 31, Validation Loss is 0.488791 and Validation Accuracy is 85.363419
# Time for epoch 31 is 1.000000 mins 7.000000 secs
#
# For Epoch 32, Training Loss is 0.186879 and Training Accuracy is 93.341184
# For Epoch 32, Validation Loss is 0.491410 and Validation Accuracy is 85.403355
# Time for epoch 32 is 1.000000 mins 6.000000 secs
#
# For Epoch 33, Training Loss is 0.183526 and Training Accuracy is 93.583363
# For Epoch 33, Validation Loss is 0.496757 and Validation Accuracy is 85.223642
# Time for epoch 33 is 1.000000 mins 6.000000 secs
#
# For Epoch 34, Training Loss is 0.177113 and Training Accuracy is 93.732225
# For Epoch 34, Validation Loss is 0.471067 and Validation Accuracy is 85.682907
# Time for epoch 34 is 1.000000 mins 6.000000 secs
#
# For Epoch 35, Training Loss is 0.170466 and Training Accuracy is 93.969961
# For Epoch 35, Validation Loss is 0.503299 and Validation Accuracy is 85.323482
# Time for epoch 35 is 1.000000 mins 7.000000 secs
#
# For Epoch 36, Training Loss is 0.163860 and Training Accuracy is 94.336562
# For Epoch 36, Validation Loss is 0.525301 and Validation Accuracy is 84.484824
# Time for epoch 36 is 1.000000 mins 7.000000 secs
#
# For Epoch 37, Training Loss is 0.155450 and Training Accuracy is 94.474316
# For Epoch 37, Validation Loss is 0.507394 and Validation Accuracy is 84.964058
# Time for epoch 37 is 1.000000 mins 6.000000 secs
#
# For Epoch 38, Training Loss is 0.153642 and Training Accuracy is 94.512087
# For Epoch 38, Validation Loss is 0.490332 and Validation Accuracy is 85.762780
# Time for epoch 38 is 1.000000 mins 6.000000 secs
#
# For Epoch 39, Training Loss is 0.144221 and Training Accuracy is 94.874245
# For Epoch 39, Validation Loss is 0.495141 and Validation Accuracy is 86.222045
# Time for epoch 39 is 1.000000 mins 6.000000 secs
#
# For Epoch 40, Training Loss is 0.139520 and Training Accuracy is 95.043103
# For Epoch 40, Validation Loss is 0.516318 and Validation Accuracy is 85.223642
# Time for epoch 40 is 1.000000 mins 6.000000 secs
#
# For Epoch 41, Training Loss is 0.137743 and Training Accuracy is 95.154195
# For Epoch 41, Validation Loss is 0.497000 and Validation Accuracy is 85.742812
# Time for epoch 41 is 1.000000 mins 6.000000 secs
#
# For Epoch 42, Training Loss is 0.132896 and Training Accuracy is 95.298614
# For Epoch 42, Validation Loss is 0.516830 and Validation Accuracy is 85.662939
# Time for epoch 42 is 1.000000 mins 5.000000 secs
#
# For Epoch 43, Training Loss is 0.132708 and Training Accuracy is 95.363047
# For Epoch 43, Validation Loss is 0.520998 and Validation Accuracy is 85.563099
# Time for epoch 43 is 1.000000 mins 6.000000 secs
#
# For Epoch 44, Training Loss is 0.125774 and Training Accuracy is 95.656328
# For Epoch 44, Validation Loss is 0.485368 and Validation Accuracy is 86.142173
# Time for epoch 44 is 1.000000 mins 6.000000 secs
#
# For Epoch 45, Training Loss is 0.117126 and Training Accuracy is 95.831852
# For Epoch 45, Validation Loss is 0.523870 and Validation Accuracy is 85.483227
# Time for epoch 45 is 1.000000 mins 6.000000 secs
#
# For Epoch 46, Training Loss is 0.116377 and Training Accuracy is 95.927391
# For Epoch 46, Validation Loss is 0.518404 and Validation Accuracy is 86.182109
# Time for epoch 46 is 1.000000 mins 6.000000 secs
#
# For Epoch 47, Training Loss is 0.115222 and Training Accuracy is 95.985158
# For Epoch 47, Validation Loss is 0.508301 and Validation Accuracy is 86.841054
# Time for epoch 47 is 1.000000 mins 6.000000 secs
#
# For Epoch 48, Training Loss is 0.113220 and Training Accuracy is 96.029595
# For Epoch 48, Validation Loss is 0.545954 and Validation Accuracy is 85.642971
# Time for epoch 48 is 1.000000 mins 6.000000 secs
#
# For Epoch 49, Training Loss is 0.108563 and Training Accuracy is 96.198454
# For Epoch 49, Validation Loss is 0.516344 and Validation Accuracy is 85.902556
# Time for epoch 49 is 1.000000 mins 6.000000 secs
#
# For Epoch 50, Training Loss is 0.103478 and Training Accuracy is 96.413971
# For Epoch 50, Validation Loss is 0.539822 and Validation Accuracy is 85.423323
# Time for epoch 50 is 1.000000 mins 6.000000 secs
#
# For Epoch 51, Training Loss is 0.099351 and Training Accuracy is 96.511731
# For Epoch 51, Validation Loss is 0.514804 and Validation Accuracy is 86.162141
# Time for epoch 51 is 1.000000 mins 6.000000 secs
#
# For Epoch 52, Training Loss is 0.100162 and Training Accuracy is 96.451742
# For Epoch 52, Validation Loss is 0.514680 and Validation Accuracy is 86.621406
# Time for epoch 52 is 1.000000 mins 6.000000 secs
#
# For Epoch 53, Training Loss is 0.096657 and Training Accuracy is 96.562833
# For Epoch 53, Validation Loss is 0.532990 and Validation Accuracy is 86.082268
# Time for epoch 53 is 1.000000 mins 5.000000 secs
#
# For Epoch 54, Training Loss is 0.092314 and Training Accuracy is 96.745023
# For Epoch 54, Validation Loss is 0.502027 and Validation Accuracy is 86.222045
# Time for epoch 54 is 1.000000 mins 6.000000 secs
#
# For Epoch 55, Training Loss is 0.095003 and Training Accuracy is 96.713918
# For Epoch 55, Validation Loss is 0.475521 and Validation Accuracy is 86.381789
# Time for epoch 55 is 1.000000 mins 6.000000 secs
#
# For Epoch 56, Training Loss is 0.088776 and Training Accuracy is 96.976093
# For Epoch 56, Validation Loss is 0.501548 and Validation Accuracy is 86.781150
# Time for epoch 56 is 1.000000 mins 6.000000 secs
#
# For Epoch 57, Training Loss is 0.085051 and Training Accuracy is 97.062744
# For Epoch 57, Validation Loss is 0.552490 and Validation Accuracy is 86.082268
# Time for epoch 57 is 1.000000 mins 6.000000 secs
#
# For Epoch 58, Training Loss is 0.088716 and Training Accuracy is 96.889442
# For Epoch 58, Validation Loss is 0.525704 and Validation Accuracy is 86.741214
# Time for epoch 58 is 1.000000 mins 6.000000 secs
#
# For Epoch 59, Training Loss is 0.084617 and Training Accuracy is 96.958319
# For Epoch 59, Validation Loss is 0.555574 and Validation Accuracy is 86.621406
# Time for epoch 59 is 1.000000 mins 6.000000 secs
#
# For Epoch 60, Training Loss is 0.083856 and Training Accuracy is 97.033861
# For Epoch 60, Validation Loss is 0.520529 and Validation Accuracy is 86.601438
# Time for epoch 60 is 1.000000 mins 6.000000 secs
#
# For Epoch 61, Training Loss is 0.075495 and Training Accuracy is 97.353804
# For Epoch 61, Validation Loss is 0.567355 and Validation Accuracy is 86.521565
# Time for epoch 61 is 1.000000 mins 6.000000 secs
#
# For Epoch 62, Training Loss is 0.078609 and Training Accuracy is 97.227160
# For Epoch 62, Validation Loss is 0.516819 and Validation Accuracy is 86.761182
# Time for epoch 62 is 1.000000 mins 6.000000 secs
#
# For Epoch 63, Training Loss is 0.073797 and Training Accuracy is 97.400462
# For Epoch 63, Validation Loss is 0.528845 and Validation Accuracy is 85.982428
# Time for epoch 63 is 1.000000 mins 6.000000 secs
#
# For Epoch 64, Training Loss is 0.074738 and Training Accuracy is 97.427124
# For Epoch 64, Validation Loss is 0.553902 and Validation Accuracy is 86.801118
# Time for epoch 64 is 1.000000 mins 5.000000 secs
#
# For Epoch 65, Training Loss is 0.071776 and Training Accuracy is 97.458230
# For Epoch 65, Validation Loss is 0.534779 and Validation Accuracy is 86.301917
# Time for epoch 65 is 1.000000 mins 6.000000 secs
#
# For Epoch 66, Training Loss is 0.074043 and Training Accuracy is 97.400462
# For Epoch 66, Validation Loss is 0.552412 and Validation Accuracy is 86.142173
# Time for epoch 66 is 1.000000 mins 6.000000 secs
#
# For Epoch 67, Training Loss is 0.067497 and Training Accuracy is 97.653750
# For Epoch 67, Validation Loss is 0.540708 and Validation Accuracy is 86.841054
# Time for epoch 67 is 1.000000 mins 6.000000 secs
#
# For Epoch 68, Training Loss is 0.069320 and Training Accuracy is 97.520441
# For Epoch 68, Validation Loss is 0.532165 and Validation Accuracy is 86.801118
# Time for epoch 68 is 1.000000 mins 6.000000 secs
#
# For Epoch 69, Training Loss is 0.066344 and Training Accuracy is 97.664860
# For Epoch 69, Validation Loss is 0.559089 and Validation Accuracy is 85.782748
# Time for epoch 69 is 1.000000 mins 6.000000 secs
#
# For Epoch 70, Training Loss is 0.067982 and Training Accuracy is 97.613758
# For Epoch 70, Validation Loss is 0.594616 and Validation Accuracy is 86.122204
# Time for epoch 70 is 1.000000 mins 6.000000 secs
#
# For Epoch 71, Training Loss is 0.066433 and Training Accuracy is 97.691522
# For Epoch 71, Validation Loss is 0.561714 and Validation Accuracy is 86.102236
# Time for epoch 71 is 1.000000 mins 7.000000 secs
#
# For Epoch 72, Training Loss is 0.060958 and Training Accuracy is 97.873711
# For Epoch 72, Validation Loss is 0.540900 and Validation Accuracy is 86.801118
# Time for epoch 72 is 1.000000 mins 5.000000 secs
#
# For Epoch 73, Training Loss is 0.059568 and Training Accuracy is 97.889264
# For Epoch 73, Validation Loss is 0.534592 and Validation Accuracy is 86.541534
# Time for epoch 73 is 1.000000 mins 6.000000 secs
#
# For Epoch 74, Training Loss is 0.062260 and Training Accuracy is 97.742624
# For Epoch 74, Validation Loss is 0.538802 and Validation Accuracy is 86.841054
# Time for epoch 74 is 1.000000 mins 6.000000 secs
#
# For Epoch 75, Training Loss is 0.060213 and Training Accuracy is 97.922592
# For Epoch 75, Validation Loss is 0.559493 and Validation Accuracy is 86.461661
# Time for epoch 75 is 1.000000 mins 6.000000 secs
#
# For Epoch 76, Training Loss is 0.057985 and Training Accuracy is 98.018130
# For Epoch 76, Validation Loss is 0.569571 and Validation Accuracy is 86.501597
# Time for epoch 76 is 1.000000 mins 5.000000 secs
#
# For Epoch 77, Training Loss is 0.058742 and Training Accuracy is 97.967028
# For Epoch 77, Validation Loss is 0.567384 and Validation Accuracy is 86.841054
# Time for epoch 77 is 1.000000 mins 6.000000 secs
#
# For Epoch 78, Training Loss is 0.054070 and Training Accuracy is 98.091450
# For Epoch 78, Validation Loss is 0.563482 and Validation Accuracy is 86.541534
# Time for epoch 78 is 1.000000 mins 6.000000 secs
#
# For Epoch 79, Training Loss is 0.052581 and Training Accuracy is 98.229204
# For Epoch 79, Validation Loss is 0.574936 and Validation Accuracy is 87.000799
# Time for epoch 79 is 1.000000 mins 6.000000 secs
#
# For Epoch 80, Training Loss is 0.053531 and Training Accuracy is 98.144774
# For Epoch 80, Validation Loss is 0.592284 and Validation Accuracy is 86.142173
# Time for epoch 80 is 1.000000 mins 6.000000 secs
#
# For Epoch 81, Training Loss is 0.051978 and Training Accuracy is 98.222538
# For Epoch 81, Validation Loss is 0.565565 and Validation Accuracy is 86.042332
# Time for epoch 81 is 1.000000 mins 6.000000 secs
#
# For Epoch 82, Training Loss is 0.055358 and Training Accuracy is 98.118112
# For Epoch 82, Validation Loss is 0.535338 and Validation Accuracy is 87.000799
# Time for epoch 82 is 1.000000 mins 6.000000 secs
#
# For Epoch 83, Training Loss is 0.049070 and Training Accuracy is 98.302524
# For Epoch 83, Validation Loss is 0.562013 and Validation Accuracy is 86.561502
# Time for epoch 83 is 1.000000 mins 6.000000 secs
#
# For Epoch 84, Training Loss is 0.050330 and Training Accuracy is 98.260309
# For Epoch 84, Validation Loss is 0.538399 and Validation Accuracy is 87.060703
# Time for epoch 84 is 1.000000 mins 5.000000 secs
#
# For Epoch 85, Training Loss is 0.049586 and Training Accuracy is 98.253644
# For Epoch 85, Validation Loss is 0.568950 and Validation Accuracy is 86.501597
# Time for epoch 85 is 1.000000 mins 6.000000 secs
#
# For Epoch 86, Training Loss is 0.046762 and Training Accuracy is 98.358070
# For Epoch 86, Validation Loss is 0.533539 and Validation Accuracy is 87.599840
# Time for epoch 86 is 1.000000 mins 5.000000 secs
#
# For Epoch 87, Training Loss is 0.048866 and Training Accuracy is 98.344739
# For Epoch 87, Validation Loss is 0.546255 and Validation Accuracy is 86.940895
# Time for epoch 87 is 1.000000 mins 6.000000 secs
#
# For Epoch 88, Training Loss is 0.045046 and Training Accuracy is 98.449165
# For Epoch 88, Validation Loss is 0.559956 and Validation Accuracy is 86.681310
# Time for epoch 88 is 1.000000 mins 5.000000 secs
#
# For Epoch 89, Training Loss is 0.041715 and Training Accuracy is 98.515819
# For Epoch 89, Validation Loss is 0.546076 and Validation Accuracy is 87.639776
# Time for epoch 89 is 1.000000 mins 6.000000 secs
#
# For Epoch 90, Training Loss is 0.046283 and Training Accuracy is 98.406950
# For Epoch 90, Validation Loss is 0.601101 and Validation Accuracy is 86.281949
# Time for epoch 90 is 1.000000 mins 6.000000 secs
#
# For Epoch 91, Training Loss is 0.043273 and Training Accuracy is 98.571365
# For Epoch 91, Validation Loss is 0.561243 and Validation Accuracy is 87.040735
# Time for epoch 91 is 1.000000 mins 6.000000 secs
#
# For Epoch 92, Training Loss is 0.044995 and Training Accuracy is 98.449165
# For Epoch 92, Validation Loss is 0.590906 and Validation Accuracy is 87.400160
# Time for epoch 92 is 1.000000 mins 6.000000 secs
#
# For Epoch 93, Training Loss is 0.048600 and Training Accuracy is 98.302524
# For Epoch 93, Validation Loss is 0.548456 and Validation Accuracy is 87.140575
# Time for epoch 93 is 1.000000 mins 6.000000 secs
#
# For Epoch 94, Training Loss is 0.039890 and Training Accuracy is 98.609136
# For Epoch 94, Validation Loss is 0.573452 and Validation Accuracy is 87.200479
# Time for epoch 94 is 1.000000 mins 6.000000 secs
#
# For Epoch 95, Training Loss is 0.046860 and Training Accuracy is 98.418059
# For Epoch 95, Validation Loss is 0.570277 and Validation Accuracy is 86.701278
# Time for epoch 95 is 1.000000 mins 6.000000 secs
#
# For Epoch 96, Training Loss is 0.041150 and Training Accuracy is 98.589140
# For Epoch 96, Validation Loss is 0.526676 and Validation Accuracy is 87.739617
# Time for epoch 96 is 1.000000 mins 6.000000 secs
#
# For Epoch 97, Training Loss is 0.040080 and Training Accuracy is 98.646907
# For Epoch 97, Validation Loss is 0.567236 and Validation Accuracy is 87.400160
# Time for epoch 97 is 1.000000 mins 6.000000 secs
#
# For Epoch 98, Training Loss is 0.043141 and Training Accuracy is 98.466939
# For Epoch 98, Validation Loss is 0.574301 and Validation Accuracy is 86.721246
# Time for epoch 98 is 1.000000 mins 6.000000 secs
#
# For Epoch 99, Training Loss is 0.040615 and Training Accuracy is 98.600249
# For Epoch 99, Validation Loss is 0.595662 and Validation Accuracy is 86.841054
# Time for epoch 99 is 1.000000 mins 6.000000 secs
#
# For Epoch 100, Training Loss is 0.039346 and Training Accuracy is 98.595805
# For Epoch 100, Validation Loss is 0.592331 and Validation Accuracy is 86.681310
# Time for epoch 100 is 1.000000 mins 6.000000 secs

# %%
def get_predictions(model, iterator, device):
    # model.load_state_dict(torch.load("/content/best_model")) 
    # model.optimizer=optimizer
    model.eval()

    labels = []
    probs = []
    

    for x,y in iterator:
      x = x.to(device)
      y = y.to(device)
      
      y_pred = model(x)
      labels.append(y)
      probs.append(y_pred)


    #Converting the labels and probabilities obtained to a tensor
    labels = torch.cat(labels, dim = 0)
    probs = torch.cat(probs, dim = 0)

    return labels, probs

# %%
resnet18.load_state_dict(torch.load("/content/best_model.pt")) 
resnet18.optimizer=optimizer

labels, probs = get_predictions(resnet18, test_iterator, device)

print("Accuracy on Test Data is %f%%" %(calculate_accuracy(probs, labels).to('cpu').detach().numpy()*100))
# Out:
# Accuracy on Test Data is 88.209999%
